# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
md = np.array([500,1000,1500,2000,2500,3000,3500,4000,4500,5000,5500])
spd737 = pd.read_csv('avSpeed_StdDev737.csv', names=['spd','sd'])
spd734 = pd.read_csv('avSpeed_StdDev734.csv', names=['spd','sd'])
spd739 = pd.read_csv('avSpeed_StdDev739.csv', names=['spd','sd'])
spd373 = pd.read_csv('avSpeed_StdDev373.csv', names=['spd','sd'])
spd674 = pd.read_csv('avSpeed_StdDev674.csv', names=['spd','sd'])
spd873 = pd.read_csv('avSpeed_StdDev873.csv', names=['spd','sd'])

# %%
fig, ax = plt.subplots(figsize=(10,8))
#plt.axis('tight')

ax.errorbar(md,spd737['spd'],yerr=spd737['sd'], mec='blue', capsize=2.5, marker='.')
ax.errorbar(md,spd734['spd'],yerr=spd734['sd'], mec='green', capsize=2.5, marker='.')
ax.errorbar(md,spd739['spd'],yerr=spd739['sd'], mec='red', capsize=2.5, marker='.')
ax.errorbar(md,spd373['spd'],yerr=spd373['sd'], mec='magenta', capsize=2.5, marker='.')
ax.errorbar(md,spd674['spd'],yerr=spd674['sd'], mec='cyan', capsize=2.5, marker='.')
ax.errorbar(md,spd873['spd'],yerr=spd873['sd'], mec='grey', capsize=2.5, marker='.')

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(np.arange(0,6001,step=1000))
ax.set_yticks(np.arange(0,13,step=2))

ax.set_ylabel('Speed ($\mu m/s$)', fontsize=18)
ax.set_xlabel('Motor density', fontsize=18)

ax.tick_params(labelsize=18)

ax.set_title('Motor density vs. average speed (6 filaments)', fontsize=18)

plt.savefig('motorDensity.svg',fmt='svg',dpi=3000, bbox_inches='tight')

plt.show()

# %%
bm873MD500 = pd.read_csv('bm_no873MD500.csv', names=['bm']); df1 = bm873MD500['bm'].T
bm873MD1000 = pd.read_csv('bm_no873MD1000.csv', names=['bm']); df2 = bm873MD1000['bm'].T
bm873MD1500 = pd.read_csv('bm_no873MD1500.csv', names=['bm']); df3 = bm873MD1500['bm'].T
bm873MD2000 = pd.read_csv('bm_no873MD2000.csv', names=['bm']); df4 = bm873MD2000['bm'].T
bm873MD2500 = pd.read_csv('bm_no873MD2500.csv', names=['bm']); df5 = bm873MD2500['bm'].T
bm873MD3000 = pd.read_csv('bm_no873MD3000.csv', names=['bm']); df6 = bm873MD3000['bm'].T
bm873MD3500 = pd.read_csv('bm_no873MD3500.csv', names=['bm']); df7 = bm873MD3500['bm'].T
bm873MD4000 = pd.read_csv('bm_no873MD4000.csv', names=['bm']); df8 = bm873MD4000['bm'].T
bm873MD4500 = pd.read_csv('bm_no873MD4500.csv', names=['bm']); df9 = bm873MD4500['bm'].T
bm873MD5000 = pd.read_csv('bm_no873MD5000.csv', names=['bm']); df10 = bm873MD5000['bm'].T
bm873MD5500 = pd.read_csv('bm_no873MD5500.csv', names=['bm']); df11 = bm873MD5500['bm'].T

bm373MD500 = pd.read_csv('bm_no373MD500.csv', names=['bm']); df12 = bm373MD500['bm'].T
bm373MD1000 = pd.read_csv('bm_no373MD1000.csv', names=['bm']); df13 = bm373MD1000['bm'].T
bm373MD1500 = pd.read_csv('bm_no373MD1500.csv', names=['bm']); df14 = bm373MD1500['bm'].T
bm373MD2000 = pd.read_csv('bm_no373MD2000.csv', names=['bm']); df15 = bm373MD2000['bm'].T
bm373MD2500 = pd.read_csv('bm_no373MD2500.csv', names=['bm']); df16 = bm373MD2500['bm'].T
bm373MD3000 = pd.read_csv('bm_no373MD3000.csv', names=['bm']); df17 = bm373MD3000['bm'].T
bm373MD3500 = pd.read_csv('bm_no373MD3500.csv', names=['bm']); df18 = bm373MD3500['bm'].T
bm373MD4000 = pd.read_csv('bm_no373MD4000.csv', names=['bm']); df19 = bm373MD4000['bm'].T
bm373MD4500 = pd.read_csv('bm_no373MD4500.csv', names=['bm']); df20 = bm373MD4500['bm'].T
bm373MD5000 = pd.read_csv('bm_no373MD5000.csv', names=['bm']); df21 = bm373MD5000['bm'].T
bm373MD5500 = pd.read_csv('bm_no373MD5500.csv', names=['bm']); df22 = bm373MD5500['bm'].T

# %%
plt.figure(figsize=(16,6))

plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)
plt.axes().set_aspect('equal')

byn = 20

plt.subplot(2,5,1)
(mu,sigma)=(df2.mean(),np.std(df2))
plt.hist(df2,byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
plt.title(r'MD = 1000, $\mu=%d,\ \sigma=%d$' %(mu, sigma))
plt.ylabel('Probability density')
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
plt.xticks(np.arange(0,80,step=10))

plt.subplot(2,5,2)
(mu,sigma)=(df3.mean(),np.std(df3))
plt.hist(df3,byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
plt.title(r'MD = 1500, $\mu=%d,\ \sigma=%d$' %(mu, sigma))
#plt.xlabel('Binding motor number')
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
plt.xticks(np.arange(0,80,step=10))

plt.subplot(2,5,3)
(mu,sigma)=(df4.mean(),np.std(df4))
plt.hist(df4,byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
plt.title(r'MD = 2000, $\mu=%d,\ \sigma=%d$' %(mu, sigma))
#plt.xlabel('Binding motor number')
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
plt.xticks(np.arange(0,80,step=10))

plt.subplot(2,5,4)
(mu,sigma)=(df5.mean(),np.std(df5))
plt.hist(df5,byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
plt.title(r'MD = 2500, $\mu=%d,\ \sigma=%d$' %(mu, sigma))
#plt.xlabel('Binding motor number')
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
plt.xticks(np.arange(0,80,step=10))

plt.subplot(2,5,5)
(mu,sigma)=(df6.mean(),np.std(df6))
plt.hist(df6,byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
plt.title(r'MD = 3000, $\mu=%d,\ \sigma=%d$' %(mu, sigma))
#plt.xlabel('Binding motor number')
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
plt.xticks(np.arange(0,80,step=10))

plt.subplot(2,5,6)
(mu,sigma)=(df7.mean(),np.std(df7))
plt.hist(df7,byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
plt.title(r'MD = 3500, $\mu=%d,\ \sigma=%d$' %(mu, sigma))
plt.xlabel('Binding motor number')
plt.ylabel('Probability density')
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
plt.xticks(np.arange(0,80,step=10))

plt.subplot(2,5,7)
(mu,sigma)=(df8.mean(),np.std(df8))
plt.hist(df8,byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
plt.title(r'MD = 4000, $\mu=%d,\ \sigma=%d$' %(mu, sigma))
plt.xlabel('Binding motor number')
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
plt.xticks(np.arange(0,80,step=10))

plt.subplot(2,5,8)
(mu,sigma)=(df9.mean(),np.std(df9))
plt.hist(df9,byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
plt.title(r'MD = 4500, $\mu=%d,\ \sigma=%d$' %(mu, sigma))
plt.xlabel('Binding motor number')
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
plt.xticks(np.arange(0,80,step=10))

plt.subplot(2,5,9)
(mu,sigma)=(df10.mean(),np.std(df10))
plt.hist(df10,byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
plt.title(r'MD = 5000, $\mu=%d,\ \sigma=%d$' %(mu, sigma))
plt.xlabel('Binding motor number')
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
plt.xticks(np.arange(0,80,step=10))

plt.subplot(2,5,10)
(mu,sigma)=(df11.mean(),np.std(df11))
plt.hist(df11,byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
plt.title(r'MD = 5500, $\mu=%d,\ \sigma=%d$' %(mu, sigma))
plt.xlabel('Binding motor number')
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
plt.xticks(np.arange(0,80,step=10))

plt.savefig('bm_1.svg',fmt='svg',dpi=2000, bbox_inches='tight')

plt.show()

# %%
np.random.random_integers(200,400,10) # generate simulation random seed
# Out:
# /home/nitta/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: This function is deprecated. Please call randint(200, 400 + 1) instead
#   """Entry point for launching an IPython kernel.
# array([245, 209, 311, 310, 278, 240, 251, 393, 297, 318])

# %%
#doing with for-loop for short code

# %%
df = np.array([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11])

# %%
#data for filament of random number 873, from MD500 to MD5500
bm873 = []; md = 500 #simulated in PC7

for j in range(11):
    bm873MD = pd.read_csv('bm_no873MD'+str(md)+'.csv', names=['bm'])
    bm873MD = bm873MD['bm'].T
    bm873.append(bm873MD)
    md = md+500
bm873 = np.array(bm873)

# %%
np.array_equal(bm873, df)
# Out:
# True

# %%
plt.figure(figsize=(12,6))
plt.axis('tight')
plt.suptitle('Binding Motor Number vs. Probability Density [ATP = 2000, R = 1.0, Step size = 10 nm, Filament 1]', fontsize=16)

plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)
plt.axes().set_aspect('equal')

byn = 20; md = 1500


#(mu,sigma)=norm.fit(df6)
#n,bins,patches = plt.hist(df6,byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
#plt.plot(bins,1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2)),'b-',lw=1.3)


for i in range(2,8):
    plt.subplot(2,3,i-1)
    (mu,sigma)=norm.fit(bm873[i])
    n,bins,patches = plt.hist(bm873[i],byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
    #(mu,sigma)=(np.round(bm873[i].mean(),0), np.round(np.std(bm873[i]),0))
    #plt.hist(bm873[i],byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
    plt.title(r'MD = %d, $\mu=%.2f,\ \sigma=%.2f$' %(md, mu, sigma))
    plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
    if i>2:
        plt.plot(bins,1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2)),'b-',lw=1.3)
        plt.yticks(np.arange(0,0.17,step=0.04), fontsize=14)
        plt.xticks(np.arange(0,61,step=10))
    elif i<3 and i>0:
        plt.yticks(np.arange(0,2.1,step=0.4), fontsize=14)
        plt.xticks(np.arange(0,31,step=5))
    elif i<1:
        plt.yticks(np.arange(0,21,step=5), fontsize=14)
        plt.xticks(np.arange(0,2.5,step=0.5))
    if i==2 or i==5:
        plt.ylabel('Density', fontsize=14)
    if i>4:
        plt.xlabel('Motor number', fontsize=14)
    md = md+500
plt.savefig('bmHist873.svg',fmt='svg',dpi=2000, bbox_inches='tight')

# %%
plt.figure(figsize=(12,6))
plt.suptitle('Leading Tip Trajectory [Filament 1]', fontsize=16)
plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)
plt.axes().set_aspect('equal')

md = 1500

for i in range(2,8):
    plt.subplot(2,3,i-1)
    plt.plot(AF873[i]['x'],AF873[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=7)
    plt.xticks(np.arange(-15,26,step=10),fontsize=14)
    plt.yticks(np.arange(-20,26,step=10),fontsize=14)
    plt.title('MD = %d'%(md), fontsize=14)
    if i==2 or i==5:
        plt.ylabel('Y ($\mu m$)', fontsize=16)
    if i>4:
        plt.xlabel('X ($\mu m$)', fontsize=16)
    md = md+500
plt.savefig('traj873.svg',fmt='svg',dpi=2000, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(8, 6))

#plt.axis('tight')
plt.suptitle('Binding Motor Number vs. Probability Density [ATP = 2000, R = 1.0, Step size = 10 nm, Filament 1]', fontsize=16)

plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)
#plt.axes().set_aspect('equal')

fig.add_subplot(221)
(mu,sigma)=norm.fit(bm873[3])
n,bins,patches = plt.hist(bm873[3],byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
plt.plot(bins,1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2)),'b-',lw=1.3)

#left,bottom,width,height= 0.2, 0.6, 0.3, 0.25

fig.add_axes([0.33, 0.73, 0.13, 0.13], facecolor='none')
plt.plot(AF873[3]['x'],AF873[3]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=7)

fig.add_subplot(222)
(mu,sigma)=norm.fit(bm873[4])
n,bins,patches = plt.hist(bm873[4],byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
plt.plot(bins,1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2)),'b-',lw=1.3)

fig.add_axes([0.75,0.73,0.13,0.13], facecolor='none')
plt.plot(AF873[4]['x'],AF873[4]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=7)

fig.add_subplot(223)
(mu,sigma)=norm.fit(bm873[5])
n,bins,patches = plt.hist(bm873[5],byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
plt.plot(bins,1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2)),'b-',lw=1.3)

fig.add_axes([0.33,0.31,0.13,0.13], facecolor='none')
plt.plot(AF873[5]['x'],AF873[5]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=7)

fig.add_subplot(224)
(mu,sigma)=norm.fit(bm873[6])
n,bins,patches = plt.hist(bm873[6],byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
plt.plot(bins,1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2)),'b-',lw=1.3)

fig.add_axes([0.57,0.2,0.3,0.25], facecolor='none')
plt.plot(AF873[6]['x'],AF873[6]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=7)

# %%
bm873[3] # no detach
# Out:
# array([13, 14, 17, 13, 17, 11, 18, 12,  8, 14, 18, 16, 11, 16, 10, 17, 15,
#        15,  7, 14, 17, 12, 14, 14, 19, 12, 14, 15, 16, 15, 17, 24, 19, 11,
#        14, 19, 14, 10, 19, 13,  8,  6, 15,  8, 17, 20, 15, 12, 10, 15, 15,
#        14, 20, 17, 12, 20, 15,  6, 15, 17, 14, 16, 16, 21, 13, 13, 26, 15,
#        23, 13, 16, 17, 14, 14, 14, 13, 16, 23, 13, 13, 12, 19, 15, 11, 10,
#         9, 20, 17, 18, 13, 16,  9,  9, 18, 10, 16, 18,  8, 19,  8,  8, 10,
#        12, 12, 14, 20, 15, 15, 20, 16,  1,  3,  5, 21, 14, 21, 16, 15, 16,
#        13, 20, 13, 16, 18, 15, 12, 20, 11, 11, 17, 24, 16, 13, 17, 12, 21,
#        13, 20, 17, 12, 14, 12, 16, 18, 13, 21, 19, 20, 18, 22, 21, 15, 13,
#        11, 16, 14, 15, 13, 13, 16, 13, 13, 19, 13, 15, 16, 12, 16, 12, 20,
#        19, 15, 16, 13, 17, 13, 19, 15, 26, 19, 16, 14, 13, 19, 16, 15, 17,
#        15,  9, 18, 18, 19, 14, 27, 21, 18,  4,  9, 11,  5, 22, 20, 14, 13,
# ...

# %%
fig = plt.figure(figsize=(12, 6))
left,bottom,width,height= 0.235, 0.735, 0.09, 0.13

plt.suptitle('Binding Motor Number vs. Probability Density [ATP = 2000, R = 1.0, Filament 1]', fontsize=16)

plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)

byn = 20; md = 1500
Nleft = 0.285; Nleft2 = 0.0

for i in range(2,8):
    fig.add_subplot(229+i)
    (mu,sigma)=norm.fit(bm873[i])
    n,bins,patches = plt.hist(bm873[i],byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
    plt.title(r'MD = %d, $\mu=%.2f,\ \sigma=%.2f$' %(md, mu, sigma))
    plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
    if i>2:
        plt.plot(bins,1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2)),'b-',lw=1.3)
        plt.yticks(np.arange(0,0.17,step=0.04), fontsize=14)
        plt.xticks(np.arange(0,61,step=10))
    elif i<3 and i>0:
        plt.yticks(np.arange(0,2.1,step=0.4), fontsize=14)
        plt.xticks(np.arange(0,31,step=5))
    elif i<1:
        plt.yticks(np.arange(0,21,step=5), fontsize=14)
        plt.xticks(np.arange(0,2.5,step=0.5))
    if i==2 or i==5:
        plt.ylabel('Density', fontsize=14)
    if i>4:
        plt.xlabel('Motor number', fontsize=14)
    if i<3:
        ax0 = fig.add_axes([0.23,bottom,width,height], facecolor='none')
        ax0.plot(AF873[i]['x'],AF873[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=3)
        ax0.spines['right'].set_visible(False)
        ax0.spines['top'].set_visible(False)
        ax0.xaxis.set_ticks_position('bottom')
        ax0.yaxis.set_ticks_position('left')
        plt.xticks(np.arange(-15,26,step=20),fontsize=14)
        plt.yticks(np.arange(-20,26,step=20),fontsize=14)
        plt.ylabel('Y ($\mu m$)')
        plt.xlabel('X ($\mu m$)')
        plt.title('Trajectory', y=0.8)
    if i>2 and i<5:
        ax1 = fig.add_axes([left+Nleft,bottom,width,height], facecolor='none')
        ax1.plot(AF873[i]['x'],AF873[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=3)
        ax1.spines['right'].set_visible(False)
        ax1.spines['top'].set_visible(False)
        ax1.xaxis.set_ticks_position('bottom')
        ax1.yaxis.set_ticks_position('left')
        ax1.set_yticklabels([])
        ax1.set_xticklabels([])
        plt.xticks(np.arange(-15,26,step=20),fontsize=14)
        plt.yticks(np.arange(-20,26,step=20),fontsize=14)
        Nleft = Nleft+0.285
    if i>4:
        bottom=0.3
        ax2 = fig.add_axes([left+Nleft2,bottom,width,height], facecolor='none')
        ax2.plot(AF873[i]['x'],AF873[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=3)
        ax2.spines['right'].set_visible(False)
        ax2.spines['top'].set_visible(False)
        ax2.xaxis.set_ticks_position('bottom')
        ax2.yaxis.set_ticks_position('left')
        ax2.set_yticklabels([])
        ax2.set_xticklabels([])
        plt.xticks(np.arange(-15,26,step=20),fontsize=14)
        plt.yticks(np.arange(-20,26,step=20),fontsize=14)
        Nleft2 = Nleft2+0.285
    md = md+500
    
plt.savefig('bmHist873x.svg',fmt='svg',dpi=3000, bbox_inches='tight')

# %%
AF873 = []; md = 500

for j in range(11):
    AF873MD = pd.read_csv('TipXY'+str(md)+'seed873.txt', names=['t', 'x', 'y'], delim_whitespace=True)
    AF873MD = AF873MD.drop(['t'], axis=1) # we don't need 't'. NB: dt = 0.01*1 = 0.01 sec
    AF873MD = AF873MD.iloc[0::10, :] #pick every 9th row starting from the first. Here dt = 0.01*10 = 0.1
    AF873.append(AF873MD)
    md = md+500

# %%
np.round(bm873[4].mean(),0), np.round(bm739[4].mean(),0)
# Out:
# (20.0, 21.0)

# %%
bm739 = []; md = 500  #simulated in PC6

for j in range(11):
    bm739MD = pd.read_csv('bm_no739MD'+str(md)+'.csv', names=['bm'])
    bm739MD = bm739MD['bm'].T
    bm739.append(bm739MD)
    md = md+500
bm739 = np.array(bm739)

# %%
plt.figure(figsize=(12,6))
plt.axis('tight')
plt.suptitle('Binding Motor Number vs. Probability Density [ATP = 2000, R = 1.0, Step size = 10 nm, Filament 2]', fontsize=16)

plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)

byn = 20; md = 1500

for i in range(2,8):
    plt.subplot(2,3,i-1)
    (mu,sigma)=norm.fit(bm739[i])
    n,bins,patches = plt.hist(bm739[i],byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
    plt.title(r'MD = %d, $\mu=%.2f,\ \sigma=%.2f$' %(md, mu, sigma))
    plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
    if i>2:
        plt.plot(bins,1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2)),'b-',lw=1.3)
        plt.yticks(np.arange(0,0.17,step=0.04), fontsize=14)
        plt.xticks(np.arange(0,61,step=10))
    elif i<3 and i>0:
        plt.yticks(np.arange(0,2.1,step=0.4), fontsize=14)
        plt.xticks(np.arange(0,31,step=5))
    elif i<1:
        plt.yticks(np.arange(0,6,step=1), fontsize=14)
        plt.xticks(np.arange(0,11,step=2))
    if i==2 or i==5:
        plt.ylabel('Density', fontsize=14)
    if i>4:
        plt.xlabel('Motor number', fontsize=14)
    md = md+500
plt.savefig('bmHist739.svg',fmt='svg',dpi=2000, bbox_inches='tight')

# %%
AF739 = []; md = 500

for j in range(11):
    AF739MD = pd.read_csv('TipXY'+str(md)+'seed739.txt', names=['t', 'x', 'y'], delim_whitespace=True)
    AF739MD = AF739MD.drop(['t'], axis=1) 
    AF739MD = AF739MD.iloc[0::10, :] 
    AF739.append(AF739MD)
    md = md+500

# %%
plt.figure(figsize=(12,6))
plt.suptitle('Leading Tip Trajectory [Filament 2]', fontsize=16)
plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)
plt.axes().set_aspect('equal')

md = 1500

for i in range(2,8):
    plt.subplot(2,3,i-1)
    plt.plot(AF739[i]['x'],AF739[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=7)
    plt.xticks(np.arange(-15,26,step=10),fontsize=14)
    plt.yticks(np.arange(-20,26,step=10),fontsize=14)
    plt.title('MD = %d'%(md), fontsize=14)
    if i==2 or i==5:
        plt.ylabel('Y ($\mu m$)', fontsize=16)
    if i>4:
        plt.xlabel('X ($\mu m$)', fontsize=16)
    md = md+500
plt.savefig('traj739.svg',fmt='svg',dpi=2000, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(12, 6))
left,bottom,width,height= 0.235, 0.735, 0.09, 0.13

plt.suptitle('Binding Motor Number vs. Probability Density [ATP = 2000, R = 1.0, Filament 2]', fontsize=16)

plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)

byn = 20; md = 1500
Nleft = 0.285; Nleft2 = 0.0

for i in range(2,8):
    fig.add_subplot(229+i)
    (mu,sigma)=norm.fit(bm739[i])
    n,bins,patches = plt.hist(bm739[i],byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
    plt.title(r'MD = %d, $\mu=%.2f,\ \sigma=%.2f$' %(md, mu, sigma))
    plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
    if i>2:
        plt.plot(bins,1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2)),'b-',lw=1.3)
        plt.yticks(np.arange(0,0.17,step=0.04), fontsize=14)
        plt.xticks(np.arange(0,61,step=10))
    elif i<3 and i>0:
        plt.yticks(np.arange(0,2.1,step=0.4), fontsize=14)
        plt.xticks(np.arange(0,31,step=5))
    elif i<1:
        plt.yticks(np.arange(0,21,step=5), fontsize=14)
        plt.xticks(np.arange(0,2.5,step=0.5))
    if i==2 or i==5:
        plt.ylabel('Density', fontsize=14)
    if i>4:
        plt.xlabel('Motor number', fontsize=14)
    if i<3:
        ax0 = fig.add_axes([0.23,bottom,width,height], facecolor='none')
        ax0.plot(AF739[i]['x'],AF739[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=3)
        ax0.spines['right'].set_visible(False)
        ax0.spines['top'].set_visible(False)
        ax0.xaxis.set_ticks_position('bottom')
        ax0.yaxis.set_ticks_position('left')
        plt.xticks(np.arange(-15,26,step=20),fontsize=14)
        plt.yticks(np.arange(-20,26,step=20),fontsize=14)
        plt.ylabel('Y ($\mu m$)')
        plt.xlabel('X ($\mu m$)')
        plt.title('Trajectory', y=0.8)
    if i>2 and i<5:
        ax1 = fig.add_axes([left+Nleft,bottom,width,height], facecolor='none')
        ax1.plot(AF739[i]['x'],AF739[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=3)
        ax1.spines['right'].set_visible(False)
        ax1.spines['top'].set_visible(False)
        ax1.xaxis.set_ticks_position('bottom')
        ax1.yaxis.set_ticks_position('left')
        ax1.set_yticklabels([])
        ax1.set_xticklabels([])
        plt.xticks(np.arange(-15,26,step=20),fontsize=14)
        plt.yticks(np.arange(-20,26,step=20),fontsize=14)
        Nleft = Nleft+0.285
    if i>4:
        bottom=0.3
        ax2 = fig.add_axes([left+Nleft2,bottom,width,height], facecolor='none')
        ax2.plot(AF739[i]['x'],AF739[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=3)
        ax2.spines['right'].set_visible(False)
        ax2.spines['top'].set_visible(False)
        ax2.xaxis.set_ticks_position('bottom')
        ax2.yaxis.set_ticks_position('left')
        ax2.set_yticklabels([])
        ax2.set_xticklabels([])
        plt.xticks(np.arange(-15,26,step=20),fontsize=14)
        plt.yticks(np.arange(-20,26,step=20),fontsize=14)
        Nleft2 = Nleft2+0.285
    md = md+500
    
plt.savefig('bmHist739x.svg',fmt='svg',dpi=3000, bbox_inches='tight')

# %%
bm737 = []; md = 500 #simulated in PC6

for j in range(11):
    bm737MD = pd.read_csv('bm_no737MD'+str(md)+'.csv', names=['bm'])
    bm737MD = bm737MD['bm'].T
    bm737.append(bm737MD)
    md = md+500
bm737 = np.array(bm737)

# %%
bm737[3]
# Out:
# array([18, 14, 14, 14,  8, 15,  3, 18, 18, 19, 13, 21, 15, 19, 19, 13, 17,
#        10, 23, 13, 10, 16, 13, 15, 16,  8, 12, 10, 14, 24, 21, 19, 17, 12,
#        16, 16, 14, 22,  6, 15, 13, 17, 14, 13, 14, 15, 21, 13, 12,  7, 11,
#         8, 10, 15, 21, 22, 14, 15, 17, 11, 19, 23, 14, 13, 12, 14, 17, 23,
#        20, 16, 14, 11, 16, 10,  6, 13, 14, 13, 20, 16, 15, 13, 15, 17, 13,
#        17, 11, 13, 13,  7, 28,  9, 14, 19, 10, 11, 19, 14, 14, 11, 15, 10,
#         6, 15, 20, 13, 12, 23, 19, 14, 21, 11, 14, 12, 17, 20, 20, 15, 23,
#        19, 17, 15, 12, 11,  9, 11, 16, 15, 22, 21, 14, 19, 20, 13, 15, 13,
#        21, 14, 15, 14, 13,  9, 30, 14, 19, 21, 18, 21,  6,  8, 18, 16, 14,
#        10, 11, 14,  9, 15, 11, 16, 16, 12, 13, 14, 17, 10, 11, 16, 10,  6,
#         5, 18, 25, 16, 22, 13, 12, 11,  8, 16, 15,  2,  6, 11, 17, 13, 10,
#        14, 10,  9, 16, 10, 18, 11,  9, 21,  8, 17, 17, 14, 12,  8,  3,  0,
# ...

# %%
plt.figure(figsize=(12,6))
plt.axis('tight')
plt.suptitle('Binding Motor Number vs. Probability Density [ATP = 2000, R = 1.0, Step size = 10 nm, Filament 3]', fontsize=16)

plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)

byn = 20; md = 1500

for i in range(2,8):
    plt.subplot(2,3,i-1)
    (mu,sigma)=norm.fit(bm737[i])
    n,bins,patches = plt.hist(bm737[i],byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
    plt.title(r'MD = %d, $\mu=%.2f,\ \sigma=%.2f$' %(md, mu, sigma))
    plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
    if i>2:
        plt.plot(bins,1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2)),'b-',lw=1.3)
        plt.yticks(np.arange(0,0.17,step=0.04), fontsize=14)
        plt.xticks(np.arange(0,61,step=10))
    elif i<3:
        plt.yticks(np.arange(0,2.1,step=0.4), fontsize=14)
        plt.xticks(np.arange(0,31,step=5))
    if i==2 or i==5:
        plt.ylabel('Density', fontsize=14)
    if i>4:
        plt.xlabel('Motor number', fontsize=14)
    md = md+500
plt.savefig('bmHist737.svg',fmt='svg',dpi=2000, bbox_inches='tight')

# %%
AF737 = []; md = 500

for j in range(11):
    AF737MD = pd.read_csv('TipXY'+str(md)+'seed737.txt', names=['t', 'x', 'y'], delim_whitespace=True)
    AF737MD = AF737MD.drop(['t'], axis=1) 
    AF737MD = AF737MD.iloc[0::10, :] 
    AF737.append(AF737MD)
    md = md+500

# %%
plt.figure(figsize=(12,6))
plt.suptitle('Leading Tip Trajectory [Filament 3]', fontsize=16)
plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)
plt.axes().set_aspect('equal')

md = 1500

for i in range(2,8):
    plt.subplot(2,3,i-1)
    plt.plot(AF737[i]['x'],AF737[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=7)
    plt.xticks(np.arange(-15,26,step=10),fontsize=14)
    plt.yticks(np.arange(-20,26,step=10),fontsize=14)
    plt.title('MD = %d'%(md), fontsize=14)
    if i==2 or i==5:
        plt.ylabel('Y ($\mu m$)', fontsize=16)
    if i>4:
        plt.xlabel('X ($\mu m$)', fontsize=16)
    md = md+500
plt.savefig('traj737.svg',fmt='svg',dpi=2000, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(12, 6))
left,bottom,width,height= 0.235, 0.735, 0.09, 0.13

plt.suptitle('Binding Motor Number vs. Probability Density [ATP = 2000, R = 1.0, Filament 3]', fontsize=16)

plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)

byn = 20; md = 1500
Nleft = 0.285; Nleft2 = 0.0

for i in range(2,8):
    fig.add_subplot(229+i)
    (mu,sigma)=norm.fit(bm737[i])
    n,bins,patches = plt.hist(bm737[i],byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
    plt.title(r'MD = %d, $\mu=%.2f,\ \sigma=%.2f$' %(md, mu, sigma))
    plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
    if i>2:
        plt.plot(bins,1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2)),'b-',lw=1.3)
        plt.yticks(np.arange(0,0.17,step=0.04), fontsize=14)
        plt.xticks(np.arange(0,61,step=10))
    elif i<3 and i>0:
        plt.yticks(np.arange(0,2.1,step=0.4), fontsize=14)
        plt.xticks(np.arange(0,31,step=5))
    elif i<1:
        plt.yticks(np.arange(0,21,step=5), fontsize=14)
        plt.xticks(np.arange(0,2.5,step=0.5))
    if i==2 or i==5:
        plt.ylabel('Density', fontsize=14)
    if i>4:
        plt.xlabel('Motor number', fontsize=14)
    if i<3:
        ax0 = fig.add_axes([0.23,bottom,width,height], facecolor='none')
        ax0.plot(AF737[i]['x'],AF737[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=3)
        ax0.spines['right'].set_visible(False)
        ax0.spines['top'].set_visible(False)
        ax0.xaxis.set_ticks_position('bottom')
        ax0.yaxis.set_ticks_position('left')
        plt.xticks(np.arange(-15,26,step=20),fontsize=14)
        plt.yticks(np.arange(-20,26,step=20),fontsize=14)
        plt.ylabel('Y ($\mu m$)')
        plt.xlabel('X ($\mu m$)')
        plt.title('Trajectory', y=0.8)
    if i>2 and i<5:
        ax1 = fig.add_axes([left+Nleft,bottom,width,height], facecolor='none')
        ax1.plot(AF737[i]['x'],AF737[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=3)
        ax1.spines['right'].set_visible(False)
        ax1.spines['top'].set_visible(False)
        ax1.xaxis.set_ticks_position('bottom')
        ax1.yaxis.set_ticks_position('left')
        ax1.set_yticklabels([])
        ax1.set_xticklabels([])
        plt.xticks(np.arange(-15,26,step=20),fontsize=14)
        plt.yticks(np.arange(-20,26,step=20),fontsize=14)
        Nleft = Nleft+0.285
    if i>4:
        bottom=0.3
        ax2 = fig.add_axes([left+Nleft2,bottom,width,height], facecolor='none')
        ax2.plot(AF737[i]['x'],AF737[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=3)
        ax2.spines['right'].set_visible(False)
        ax2.spines['top'].set_visible(False)
        ax2.xaxis.set_ticks_position('bottom')
        ax2.yaxis.set_ticks_position('left')
        ax2.set_yticklabels([])
        ax2.set_xticklabels([])
        plt.xticks(np.arange(-15,26,step=20),fontsize=14)
        plt.yticks(np.arange(-20,26,step=20),fontsize=14)
        Nleft2 = Nleft2+0.285
    md = md+500
    
plt.savefig('bmHist737x.svg',fmt='svg',dpi=3000, bbox_inches='tight')

# %%
bm734 = []; md = 500 #simulated in PC6

for j in range(11):
    bm734MD = pd.read_csv('bm_no734MD'+str(md)+'.csv', names=['bm'])
    bm734MD = bm734MD['bm'].T
    bm734.append(bm734MD)
    md = md+500
bm734 = np.array(bm734)

# %%
plt.figure(figsize=(12,6))
plt.axis('tight')
plt.suptitle('Binding Motor Number vs. Probability Density [ATP = 2000, R = 1.0, Step size = 10 nm, Filament 4]', fontsize=16)

plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)

byn = 20; md = 1500

for i in range(2,8):
    plt.subplot(2,3,i-1)
    (mu,sigma)=norm.fit(bm734[i])
    n,bins,patches = plt.hist(bm734[i],byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
    plt.title(r'MD = %d, $\mu=%.2f,\ \sigma=%.2f$' %(md, mu, sigma))
    plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
    if i>3:
        plt.plot(bins,1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2)),'b-',lw=1.3)
        plt.yticks(np.arange(0,0.17,step=0.04), fontsize=14)
        plt.xticks(np.arange(0,61,step=10))
    elif i<4:
        plt.yticks(np.arange(0,2.1,step=0.4), fontsize=14)
        plt.xticks(np.arange(0,31,step=5))
    if i==2 or i==5:
        plt.ylabel('Density', fontsize=14)
    if i>4:
        plt.xlabel('Motor number', fontsize=14)
    md = md+500
plt.savefig('bmHist734.svg',fmt='svg',dpi=2000, bbox_inches='tight')

# %%
AF734 = []; md = 500

for j in range(11):
    AF734MD = pd.read_csv('TipXY'+str(md)+'seed734.txt', names=['t', 'x', 'y'], delim_whitespace=True)
    AF734MD = AF734MD.drop(['t'], axis=1) 
    AF734MD = AF734MD.iloc[0::10, :] 
    AF734.append(AF734MD)
    md = md+500

# %%
plt.figure(figsize=(12,6))
plt.suptitle('Leading Tip Trajectory [Filament 4]', fontsize=16)
plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)
plt.axes().set_aspect('equal')

md = 1500

for i in range(2,8):
    plt.subplot(2,3,i-1)
    plt.plot(AF734[i]['x'],AF734[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=7)
    plt.xticks(np.arange(-15,26,step=10),fontsize=14)
    plt.yticks(np.arange(-20,26,step=10),fontsize=14)
    plt.title('MD = %d'%(md), fontsize=14)
    if i==2 or i==5:
        plt.ylabel('Y ($\mu m$)', fontsize=16)
    if i>4:
        plt.xlabel('X ($\mu m$)', fontsize=16)
    md = md+500
plt.savefig('traj734.svg',fmt='svg',dpi=2000, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(12, 6))
left,bottom,width,height= 0.235, 0.735, 0.09, 0.13

plt.suptitle('Binding Motor Number vs. Probability Density [ATP = 2000, R = 1.0, Filament 4]', fontsize=16)

plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)

byn = 20; md = 1500
Nleft = 0.285; Nleft2 = 0.0

for i in range(2,8):
    fig.add_subplot(229+i)
    (mu,sigma)=norm.fit(bm734[i])
    n,bins,patches = plt.hist(bm734[i],byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
    plt.title(r'MD = %d, $\mu=%.2f,\ \sigma=%.2f$' %(md, mu, sigma))
    plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
    if i>3:
        plt.plot(bins,1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2)),'b-',lw=1.3)
        plt.yticks(np.arange(0,0.17,step=0.04), fontsize=14)
        plt.xticks(np.arange(0,61,step=10))
    elif i<2 and i>0:
        plt.yticks(np.arange(0,2.1,step=0.4), fontsize=14)
        plt.xticks(np.arange(0,31,step=5))
    elif i<4:
        plt.yticks(np.arange(0,1,step=0.2), fontsize=14)
        plt.xticks(np.arange(0,31,step=5))
    if i==2 or i==5:
        plt.ylabel('Density', fontsize=14)
    if i>4:
        plt.xlabel('Motor number', fontsize=14)
    if i<3:
        ax0 = fig.add_axes([0.23,bottom,width,height], facecolor='none')
        ax0.plot(AF734[i]['x'],AF734[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=3)
        ax0.spines['right'].set_visible(False)
        ax0.spines['top'].set_visible(False)
        ax0.xaxis.set_ticks_position('bottom')
        ax0.yaxis.set_ticks_position('left')
        plt.xticks(np.arange(-15,26,step=20),fontsize=14)
        plt.yticks(np.arange(-20,26,step=20),fontsize=14)
        plt.ylabel('Y ($\mu m$)')
        plt.xlabel('X ($\mu m$)')
        plt.title('Trajectory', y=0.8)
    if i>2 and i<5:
        ax1 = fig.add_axes([left+Nleft,bottom,width,height], facecolor='none')
        ax1.plot(AF734[i]['x'],AF734[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=3)
        ax1.spines['right'].set_visible(False)
        ax1.spines['top'].set_visible(False)
        ax1.xaxis.set_ticks_position('bottom')
        ax1.yaxis.set_ticks_position('left')
        ax1.set_yticklabels([])
        ax1.set_xticklabels([])
        plt.xticks(np.arange(-15,26,step=20),fontsize=14)
        plt.yticks(np.arange(-20,26,step=20),fontsize=14)
        Nleft = Nleft+0.285
    if i>4:
        bottom=0.3
        ax2 = fig.add_axes([left+Nleft2,bottom,width,height], facecolor='none')
        ax2.plot(AF734[i]['x'],AF734[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=3)
        ax2.spines['right'].set_visible(False)
        ax2.spines['top'].set_visible(False)
        ax2.xaxis.set_ticks_position('bottom')
        ax2.yaxis.set_ticks_position('left')
        ax2.set_yticklabels([])
        ax2.set_xticklabels([])
        plt.xticks(np.arange(-15,26,step=20),fontsize=14)
        plt.yticks(np.arange(-20,26,step=20),fontsize=14)
        Nleft2 = Nleft2+0.285
    md = md+500
    
plt.savefig('bmHist734x.svg',fmt='svg',dpi=3000, bbox_inches='tight')

# %%
bm373 = []; md = 500 #simulated in PC7

for j in range(11):
    bm373MD = pd.read_csv('bm_no373MD'+str(md)+'.csv', names=['bm'])
    bm373MD = bm373MD['bm'].T
    bm373.append(bm373MD)
    md = md+500
bm373 = np.array(bm373)

# %%
plt.figure(figsize=(12,6))
plt.axis('tight')
plt.suptitle('Binding Motor Number vs. Probability Density [ATP = 2000, R = 1.0, Step size = 10 nm, Filament 5]', fontsize=16)

plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)

byn = 20; md = 1500

for i in range(2,8):
    plt.subplot(2,3,i-1)
    (mu,sigma)=norm.fit(bm373[i])
    n,bins,patches = plt.hist(bm373[i],byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
    plt.title(r'MD = %d, $\mu=%.2f,\ \sigma=%.2f$' %(md, mu, sigma))
    plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
    if i>2:
        plt.plot(bins,1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2)),'b-',lw=1.3)
        plt.yticks(np.arange(0,0.17,step=0.04), fontsize=14)
        plt.xticks(np.arange(0,61,step=10))
    elif i<3:
        plt.yticks(np.arange(0,2.1,step=0.4), fontsize=14)
        plt.xticks(np.arange(0,31,step=5))
    if i==2 or i==5:
        plt.ylabel('Density', fontsize=14)
    if i>4:
        plt.xlabel('Motor number', fontsize=14)
    md = md+500
plt.savefig('bmHist373.svg',fmt='svg',dpi=2000, bbox_inches='tight')

# %%
AF373 = []; md = 500

for j in range(11):
    AF373MD = pd.read_csv('TipXY'+str(md)+'seed373.txt', names=['t', 'x', 'y'], delim_whitespace=True)
    AF373MD = AF373MD.drop(['t'], axis=1) 
    AF373MD = AF373MD.iloc[0::10, :] 
    AF373.append(AF373MD)
    md = md+500

# %%
plt.figure(figsize=(12,6))
plt.suptitle('Leading Tip Trajectory [Filament 5]', fontsize=16)
plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)
plt.axes().set_aspect('equal')

md = 1500

for i in range(2,8):
    plt.subplot(2,3,i-1)
    plt.plot(AF373[i]['x'],AF373[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=7)
    plt.xticks(np.arange(-15,26,step=10),fontsize=14)
    plt.yticks(np.arange(-20,26,step=10),fontsize=14)
    plt.title('MD = %d'%(md), fontsize=14)
    if i==2 or i==5:
        plt.ylabel('Y ($\mu m$)', fontsize=16)
    if i>4:
        plt.xlabel('X ($\mu m$)', fontsize=16)
    md = md+500
plt.savefig('traj373.svg',fmt='svg',dpi=2000, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(12, 6))
left,bottom,width,height= 0.235, 0.735, 0.09, 0.13

plt.suptitle('Binding Motor Number vs. Probability Density [ATP = 2000, R = 1.0, Filament 5]', fontsize=16)

plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)

byn = 20; md = 1500
Nleft = 0.285; Nleft2 = 0.0

for i in range(2,8):
    fig.add_subplot(229+i)
    (mu,sigma)=norm.fit(bm373[i])
    n,bins,patches = plt.hist(bm373[i],byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
    plt.title(r'MD = %d, $\mu=%.2f,\ \sigma=%.2f$' %(md, mu, sigma))
    plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
    if i>2:
        plt.plot(bins,1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2)),'b-',lw=1.3)
        plt.yticks(np.arange(0,0.17,step=0.04), fontsize=14)
        plt.xticks(np.arange(0,61,step=10))
    elif i<3 and i>0:
        plt.yticks(np.arange(0,2.1,step=0.4), fontsize=14)
        plt.xticks(np.arange(0,31,step=5))
    elif i<1:
        plt.yticks(np.arange(0,21,step=5), fontsize=14)
        plt.xticks(np.arange(0,2.5,step=0.5))
    if i==2 or i==5:
        plt.ylabel('Density', fontsize=14)
    if i>4:
        plt.xlabel('Motor number', fontsize=14)
    if i<3:
        ax0 = fig.add_axes([0.23,bottom,width,height], facecolor='none')
        ax0.plot(AF373[i]['x'],AF373[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=3)
        ax0.spines['right'].set_visible(False)
        ax0.spines['top'].set_visible(False)
        ax0.xaxis.set_ticks_position('bottom')
        ax0.yaxis.set_ticks_position('left')
        plt.xticks(np.arange(-15,26,step=20),fontsize=14)
        plt.yticks(np.arange(-20,26,step=20),fontsize=14)
        plt.ylabel('Y ($\mu m$)')
        plt.xlabel('X ($\mu m$)')
        plt.title('Trajectory', y=0.8)
    if i>2 and i<5:
        ax1 = fig.add_axes([left+Nleft,bottom,width,height], facecolor='none')
        ax1.plot(AF373[i]['x'],AF373[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=3)
        ax1.spines['right'].set_visible(False)
        ax1.spines['top'].set_visible(False)
        ax1.xaxis.set_ticks_position('bottom')
        ax1.yaxis.set_ticks_position('left')
        ax1.set_yticklabels([])
        ax1.set_xticklabels([])
        plt.xticks(np.arange(-15,26,step=20),fontsize=14)
        plt.yticks(np.arange(-20,26,step=20),fontsize=14)
        Nleft = Nleft+0.285
    if i>4:
        bottom=0.3
        ax2 = fig.add_axes([left+Nleft2,bottom,width,height], facecolor='none')
        ax2.plot(AF373[i]['x'],AF373[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=3)
        ax2.spines['right'].set_visible(False)
        ax2.spines['top'].set_visible(False)
        ax2.xaxis.set_ticks_position('bottom')
        ax2.yaxis.set_ticks_position('left')
        ax2.set_yticklabels([])
        ax2.set_xticklabels([])
        plt.xticks(np.arange(-15,26,step=20),fontsize=14)
        plt.yticks(np.arange(-20,26,step=20),fontsize=14)
        Nleft2 = Nleft2+0.285
    md = md+500
    
plt.savefig('bmHist373x.svg',fmt='svg',dpi=3000, bbox_inches='tight')

# %%
bm674 = []; md = 500 #simulated in PC7

for j in range(11):
    bm674MD = pd.read_csv('bm_no674MD'+str(md)+'.csv', names=['bm'])
    bm674MD = bm674MD['bm'].T
    bm674.append(bm674MD)
    md = md+500
bm674 = np.array(bm674)

# %%
plt.figure(figsize=(12,6))
plt.axis('tight')
plt.suptitle('Binding Motor Number vs. Probability Density [ATP = 2000, R = 1.0, Step size = 10 nm, Filament 6]', fontsize=16)

plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)

byn = 20; md = 1500

for i in range(2,8):
    plt.subplot(2,3,i-1)
    (mu,sigma)=norm.fit(bm674[i])
    n,bins,patches = plt.hist(bm674[i],byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
    plt.title(r'MD = %d, $\mu=%.2f,\ \sigma=%.2f$' %(md, mu, sigma))
    plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
    if i>2:
        plt.plot(bins,1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2)),'b-',lw=1.3)
        plt.yticks(np.arange(0,0.17,step=0.04), fontsize=14)
        plt.xticks(np.arange(0,61,step=10))
    elif i<3:
        plt.yticks(np.arange(0,2.1,step=0.4), fontsize=14)
        plt.xticks(np.arange(0,31,step=5))
    if i==2 or i==5:
        plt.ylabel('Density', fontsize=14)
    if i>4:
        plt.xlabel('Motor number', fontsize=14)
    md = md+500
plt.savefig('bmHist674.svg',fmt='svg',dpi=2000, bbox_inches='tight')

# %%
AF674 = []; md = 500

for j in range(11):
    AF674MD = pd.read_csv('TipXY'+str(md)+'seed674.txt', names=['t', 'x', 'y'], delim_whitespace=True)
    AF674MD = AF674MD.drop(['t'], axis=1) 
    AF674MD = AF674MD.iloc[0::10, :] 
    AF674.append(AF674MD)
    md = md+500

# %%
plt.figure(figsize=(12,6))
plt.suptitle('Leading Tip Trajectory [Filament 6]', fontsize=16)
plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)
plt.axes().set_aspect('equal')

md = 1500

for i in range(2,8):
    plt.subplot(2,3,i-1)
    plt.plot(AF674[i]['x'],AF674[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=7)
    plt.xticks(np.arange(-15,26,step=10),fontsize=14)
    plt.yticks(np.arange(-20,26,step=10),fontsize=14)
    plt.title('MD = %d'%(md), fontsize=14)
    if i==2 or i==5:
        plt.ylabel('Y ($\mu m$)', fontsize=16)
    if i>4:
        plt.xlabel('X ($\mu m$)', fontsize=16)
    md = md+500
plt.savefig('traj674.svg',fmt='svg',dpi=2000, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(12, 6))
left,bottom,width,height= 0.235, 0.735, 0.09, 0.13

plt.suptitle('Binding Motor Number vs. Probability Density [ATP = 2000, R = 1.0, Filament 6]', fontsize=16)

plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)

byn = 20; md = 1500
Nleft = 0.285; Nleft2 = 0.0

for i in range(2,8):
    fig.add_subplot(229+i)
    (mu,sigma)=norm.fit(bm674[i])
    n,bins,patches = plt.hist(bm674[i],byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
    plt.title(r'MD = %d, $\mu=%.2f,\ \sigma=%.2f$' %(md, mu, sigma))
    plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
    if i>2:
        plt.plot(bins,1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2)),'b-',lw=1.3)
        plt.yticks(np.arange(0,0.17,step=0.04), fontsize=14)
        plt.xticks(np.arange(0,61,step=10))
    elif i<3 and i>0:
        plt.yticks(np.arange(0,2.1,step=0.4), fontsize=14)
        plt.xticks(np.arange(0,31,step=5))
    elif i<1:
        plt.yticks(np.arange(0,21,step=5), fontsize=14)
        plt.xticks(np.arange(0,2.5,step=0.5))
    if i==2 or i==5:
        plt.ylabel('Density', fontsize=14)
    if i>4:
        plt.xlabel('Motor number', fontsize=14)
    if i<3:
        ax0 = fig.add_axes([0.23,bottom,width,height], facecolor='none')
        ax0.plot(AF674[i]['x'],AF674[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=3)
        ax0.spines['right'].set_visible(False)
        ax0.spines['top'].set_visible(False)
        ax0.xaxis.set_ticks_position('bottom')
        ax0.yaxis.set_ticks_position('left')
        plt.xticks(np.arange(-15,26,step=20),fontsize=14)
        plt.yticks(np.arange(-20,26,step=20),fontsize=14)
        plt.ylabel('Y ($\mu m$)')
        plt.xlabel('X ($\mu m$)')
        plt.title('Trajectory', y=0.8)
    if i>2 and i<5:
        ax1 = fig.add_axes([left+Nleft,bottom,width,height], facecolor='none')
        ax1.plot(AF674[i]['x'],AF674[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=3)
        ax1.spines['right'].set_visible(False)
        ax1.spines['top'].set_visible(False)
        ax1.xaxis.set_ticks_position('bottom')
        ax1.yaxis.set_ticks_position('left')
        ax1.set_yticklabels([])
        ax1.set_xticklabels([])
        plt.xticks(np.arange(-15,26,step=20),fontsize=14)
        plt.yticks(np.arange(-20,26,step=20),fontsize=14)
        Nleft = Nleft+0.285
    if i>4:
        bottom=0.3
        ax2 = fig.add_axes([left+Nleft2,bottom,width,height], facecolor='none')
        ax2.plot(AF674[i]['x'],AF674[i]['y'], label='Leading tip', color='red', marker='.', linestyle='-', linewidth=0.5, markersize=3)
        ax2.spines['right'].set_visible(False)
        ax2.spines['top'].set_visible(False)
        ax2.xaxis.set_ticks_position('bottom')
        ax2.yaxis.set_ticks_position('left')
        ax2.set_yticklabels([])
        ax2.set_xticklabels([])
        plt.xticks(np.arange(-15,26,step=20),fontsize=14)
        plt.yticks(np.arange(-20,26,step=20),fontsize=14)
        Nleft2 = Nleft2+0.285
    md = md+500
    
plt.savefig('bmHist674x.svg',fmt='svg',dpi=3000, bbox_inches='tight')
