# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
stepSize445 = np.array([2.5,5,7.5,10])
avSpeed445_25 = np.array([0.07867,0.07244,0.08821,0.26743,0.12731,2.83353,1.92695,2.02768,1.83359,2.21410])
avSpeed445_5 = np.array([0.06265,0.08261,0.07714,2.02958,3.47704,3.53404,3.54183,3.59619,3.23122,3.17371])
avSpeed445_75 = np.array([0.08111,0.07345,4.29688,6.08526,6.31798,5.70106,5.22937,5.30718,4.97902,4.94694])
avSpeed445_10 = np.array([0.11830,0.09510,5.83084,6.15164,6.33889,6.84546,7.17762,7.41657,7.05973,7.30847])

# %%
avSpeed01 = np.array([avSpeed445_25[0],avSpeed445_5[0],avSpeed445_75[0],avSpeed445_10[0]])
plt.plot(stepSize445,avSpeed01)

# %%
avSpeed03 = np.array([avSpeed445_25[2],avSpeed445_5[2],avSpeed445_75[2],avSpeed445_10[2]])
plt.plot(stepSize445,avSpeed03)

# %%
avSpeed04 = np.array([avSpeed445_25[3],avSpeed445_5[3],avSpeed445_75[3],avSpeed445_10[3]])
plt.plot(stepSize445,avSpeed04)

# %%
avSpeed05 = np.array([avSpeed445_25[4],avSpeed445_5[4],avSpeed445_75[4],avSpeed445_10[4]])
plt.plot(stepSize445,avSpeed05)

# %%
avSpeed06 = np.array([avSpeed445_25[5],avSpeed445_5[5],avSpeed445_75[5],avSpeed445_10[5]])
plt.plot(stepSize445,avSpeed06)

# %%
avSpeed07 = np.array([avSpeed445_25[6],avSpeed445_5[6],avSpeed445_75[6],avSpeed445_10[6]])
plt.plot(stepSize445,avSpeed07)

# %%
avSpeed08 = np.array([avSpeed445_25[7],avSpeed445_5[7],avSpeed445_75[7],avSpeed445_10[7]])
plt.plot(stepSize445,avSpeed08)

# %%
avSpeed09 = np.array([avSpeed445_25[8],avSpeed445_5[8],avSpeed445_75[8],avSpeed445_10[8]])
plt.plot(stepSize445,avSpeed09)

# %%
avSpeed10 = np.array([avSpeed445_25[9],avSpeed445_5[9],avSpeed445_75[9],avSpeed445_10[9]])
plt.plot(stepSize445,avSpeed10)
