# %%
# %run preparation.py

# %%
#r=active motor ratio, AS25_1=average speed for 25 nm seed1, SD25_1=std deviation for 25 nm for seed1
columns = ['r','AS25_1','SD25_1','AS5_1','SD5_1','AS75_1','SD75_1','AS10_1','SD10_1','AS25_2','SD25_2','AS5_2','SD5_2','AS75_2','SD75_2','AS10_2','SD10_2','AS25_3','SD25_3','AS5_3','SD5_3','AS75_3','SD75_3','AS10_3','SD10_3','AS25_4','SD25_4','AS5_4','SD5_4','AS75_4','SD75_4','AS10_4','SD10_4','AS25_5','SD25_5','AS5_5','SD5_5','AS75_5','SD75_5','AS10_5','SD10_5']

df = pd.read_csv('allseed.csv', skiprows=[0], names=columns)
df
# Out:
#      r    AS25_1    SD25_1     AS5_1     SD5_1    AS75_1    SD75_1    AS10_1  \
# 0  0.1  0.091375  0.067751  0.080307  0.060033  0.095167  0.070109  0.111458
# 1  0.2  0.554063  0.460012  0.543862  0.379765  0.354374  0.211303  0.521981
# 2  0.3  0.254460  0.202485  0.209733  0.160316  3.556824  3.285247  1.459361
# 3  0.4  0.616894  0.445223  0.565134  0.482087  3.365043  3.061693  5.837942
# 4  0.5  0.105959  0.061887  0.987140  1.988144  6.053805  3.130931  6.805809
# 5  0.6  1.364987  1.523483  3.351625  1.204483  5.533283  1.419079  7.282008
# 6  0.7  0.642986  0.499020  3.840558  1.824622  4.964038  0.572878  7.492940
# 7  0.8  2.089429  1.093664  3.303895  0.763643  5.239284  0.980526  7.433262
# 8  0.9  1.846287  0.805275  3.212708  0.638979  4.713240  0.720195  7.339058
# 9  1.0  1.872378  0.652161  3.337130  0.912000  5.096002  0.970051  7.045905
#
#      SD10_1    AS25_2    ...       AS10_4    SD10_4    AS25_5    SD25_5  \
# ...

# %%
x=df['r']
y1=df['AS25_1']; dev1=df['SD25_1']
y2=df['AS5_1']; dev2=df['SD5_1']
y3=df['AS75_1']; dev3=df['SD75_1']
y4=df['AS10_1']; dev4=df['SD10_1']

y5=df['AS25_2']; dev5=df['SD25_2']
y6=df['AS5_2']; dev6=df['SD5_2']
y7=df['AS75_2']; dev7=df['SD75_2']
y8=df['AS10_2']; dev8=df['SD10_2']

y9=df['AS25_3']; dev9=df['SD25_3']
y10=df['AS5_3']; dev10=df['SD5_3']
y11=df['AS75_3']; dev11=df['SD75_3']
y12=df['AS10_3']; dev12=df['SD10_3']

y13=df['AS25_4']; dev13=df['SD25_4']
y14=df['AS5_4']; dev14=df['SD5_4']
y15=df['AS75_4']; dev15=df['SD75_4']
y16=df['AS10_4']; dev16=df['SD10_4']

y17=df['AS25_5']; dev17=df['SD25_5']
y18=df['AS5_5']; dev18=df['SD5_5']
y19=df['AS75_5']; dev19=df['SD75_5']
y20=df['AS10_5']; dev20=df['SD10_5']

# %%
plt.figure(figsize=(10,6), dpi=500)

plt.errorbar(x,y1,yerr=dev1, ecolor='b', capsize=3, mec='blue', color='green', marker='D', label='2.5 nm speed deviation')
plt.errorbar(x,y2,yerr=dev2, ecolor='r', capsize=3, mec='red', color='yellow', marker='D', label='5 nm speed deviation')
plt.errorbar(x,y3,yerr=dev3, ecolor='g', capsize=3, mec='green', color='red', marker='D', label='7.5 nm speed deviation')
plt.errorbar(x,y4,yerr=dev4, ecolor='cyan', capsize=3, mec='cyan', color='magenta', marker='D', label='10 nm speed deviation')

plt.errorbar(x,y5,yerr=dev5, ecolor='b', capsize=3, mec='blue', color='green', marker='D', label='')
plt.errorbar(x,y6,yerr=dev6, ecolor='r', capsize=3, mec='red', color='yellow', marker='D', label='')
plt.errorbar(x,y7,yerr=dev7, ecolor='g', capsize=3, mec='green', color='red', marker='D', label='')
plt.errorbar(x,y8,yerr=dev8, ecolor='cyan', capsize=3, mec='cyan', color='magenta', marker='D', label='')

plt.errorbar(x,y9,yerr=dev9, ecolor='b', capsize=3, mec='blue', color='green', marker='D', label='')
plt.errorbar(x,y10,yerr=dev10, ecolor='r', capsize=3, mec='red', color='yellow', marker='D', label='')
plt.errorbar(x,y11,yerr=dev11, ecolor='g', capsize=3, mec='green', color='red', marker='D', label='')
plt.errorbar(x,y12,yerr=dev12, ecolor='cyan', capsize=3, mec='cyan', color='magenta', marker='D', label='')

plt.errorbar(x,y13,yerr=dev13, ecolor='b', capsize=3, mec='blue', color='green', marker='D', label='')
plt.errorbar(x,y14,yerr=dev14, ecolor='r', capsize=3, mec='red', color='yellow', marker='D', label='')
plt.errorbar(x,y15,yerr=dev15, ecolor='g', capsize=3, mec='green', color='red', marker='D', label='')
plt.errorbar(x,y16,yerr=dev16, ecolor='cyan', capsize=3, mec='cyan', color='magenta', marker='D', label='')

plt.errorbar(x,y17,yerr=dev17, ecolor='b', capsize=3, mec='blue', color='green', marker='D', label='')
plt.errorbar(x,y18,yerr=dev18, ecolor='r', capsize=3, mec='red', color='yellow', marker='D', label='')
plt.errorbar(x,y19,yerr=dev19, ecolor='g', capsize=3, mec='green', color='red', marker='D', label='')
plt.errorbar(x,y20,yerr=dev20, ecolor='cyan', capsize=3, mec='cyan', color='magenta', marker='D', label='')

plt.xlabel('Active motor ratio', fontdict=font); plt.ylabel('Speed ($\mu m/sec$)', fontdict=font)
plt.title('Actin Filament 1-5 Grinding Speed [ATP = 2000, MD = 3000]'); plt.legend(loc='upper left')
plt.savefig('AFsSpeeds_allseed.svg',bbox_inches='tight', format='svg',dip=300)

# %%
i0_ = np.array([y4[0],y8[0],y12[0],y16[0],y20[0]]); i0 = np.mean(i0_)
i1_ = np.array([y4[1],y8[1],y12[1],y16[1],y20[1]]); i1 = np.mean(i1_)
i2_ = np.array([y4[2],y8[2],y12[2],y16[2],y20[2]]); i2 = np.mean(i2_)
i3_ = np.array([y4[3],y8[3],y12[3],y16[3],y20[3]]); i3 = np.mean(i3_)
i4_ = np.array([y4[4],y8[4],y12[4],y16[4],y20[4]]); i4 = np.mean(i4_)
i5_ = np.array([y4[5],y8[5],y12[5],y16[5],y20[5]]); i5 = np.mean(i5_)
i6_ = np.array([y4[6],y8[6],y12[6],y16[6],y20[6]]); i6 = np.mean(i6_)
i7_ = np.array([y4[7],y8[7],y12[7],y16[7],y20[7]]); i7 = np.mean(i7_)
i8_ = np.array([y4[8],y8[8],y12[8],y16[8],y20[8]]); i8 = np.mean(i8_)
i9_ = np.array([y4[9],y8[9],y12[9],y16[9],y20[9]]); i9 = np.mean(i9_)
avi = np.array([i0,i1,i2,i3,i4,i5,i6,i7,i8,i9])

vsd0 = np.sqrt( np.sum( ((i0_-i0)**2)/(np.size(i0_)-1) ) )
vsd1 = np.sqrt( np.sum( ((i1_-i1)**2)/(np.size(i1_)-1) ) )
vsd2 = np.sqrt( np.sum( ((i2_-i2)**2)/(np.size(i2_)-1) ) )
vsd3 = np.sqrt( np.sum( ((i3_-i3)**2)/(np.size(i3_)-1) ) )
vsd4 = np.sqrt( np.sum( ((i4_-i4)**2)/(np.size(i4_)-1) ) )
vsd5 = np.sqrt( np.sum( ((i5_-i5)**2)/(np.size(i5_)-1) ) )
vsd6 = np.sqrt( np.sum( ((i6_-i6)**2)/(np.size(i6_)-1) ) )
vsd7 = np.sqrt( np.sum( ((i7_-i7)**2)/(np.size(i7_)-1) ) )
vsd8 = np.sqrt( np.sum( ((i8_-i8)**2)/(np.size(i8_)-1) ) )
vsd9 = np.sqrt( np.sum( ((i9_-i9)**2)/(np.size(i9_)-1) ) )
vsd = np.array([vsd0,vsd1,vsd2,vsd3,vsd4,vsd5,vsd6,vsd7,vsd8,vsd9])

# %%
plt.figure(figsize=(15,7))
plt.axis('tight')
plt.suptitle('Actin Filament Grinding Speed [ATP = 2000, MD = 3000, Step size = 10 nm]', fontsize=16)

plt.subplots_adjust(wspace=0.2)
plt.subplots_adjust(hspace=0.3)

plt.subplot(2,3,1)
plt.errorbar(x,y4,yerr=dev4, mec='purple', capsize=3, marker='.',color='green',label='Speed deviation')
y4m = np.round(y4[5:].mean(),2)
plt.axhline(y4m, linestyle='--', color='gray', label='Average grinding speed')
plt.text(0.15,y4m, str(y4m), va='center', ha='center', backgroundcolor='w')
plt.title('Filament 1', fontsize=14)
plt.ylabel('Speed ($\mu m/sec$)', fontsize=14)
plt.legend(loc='upper left')
plt.xticks(np.arange(0.0,1.2,step=0.2))
plt.yticks(np.arange(0,13,step=2))
plt.ylim(0,12)
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)

plt.subplot(2,3,2)
plt.errorbar(x,y8,yerr=dev8, mec='purple', capsize=3, marker='.',color='red',label=None)
y8m = np.round(y8[5:].mean(),2)
plt.axhline(y8m, linestyle='--', color='gray', label=None)
plt.text(0.15,y8m, str(y8m), va='center', ha='center', backgroundcolor='w')
plt.title('Filament 2', fontsize=14)
plt.xticks(np.arange(0.0,1.2,step=0.2))
plt.yticks(np.arange(0,13,step=2))
plt.ylim(0,12)
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)

plt.subplot(2,3,3)
plt.errorbar(x,y12,yerr=dev12, mec='purple', capsize=3, marker='.',color='blue',label=None)
y12m = np.round(y12[5:].mean(),2)
plt.axhline(y12m, linestyle='--', color='gray', label=None)
plt.text(0.15,y12m, str(y12m), va='center', ha='center', backgroundcolor='w')
plt.title('Filament 3', fontsize=14)
plt.xticks(np.arange(0.0,1.2,step=0.2))
plt.yticks(np.arange(0,13,step=2))
plt.ylim(0,12)
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)

plt.subplot(2,3,4)
plt.errorbar(x,y16,yerr=dev16, mec='purple', capsize=3, marker='.',color='orange',label=None)
y16m = np.round(y16[5:].mean(),2)
plt.axhline(y16m, linestyle='--', color='gray', label=None)
plt.text(0.15,y16m, str(y16m), va='center', ha='center', backgroundcolor='w')
plt.title('Filament 4', fontsize=14)
plt.xlabel('Active motor ratio', fontsize=14)
plt.ylabel('Speed ($\mu m/sec$)', fontsize=14)
plt.xticks(np.arange(0.0,1.2,step=0.2))
plt.yticks(np.arange(0,13,step=2))
plt.ylim(0,12)
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)

plt.subplot(2,3,5)
plt.errorbar(x,y20,yerr=dev20, mec='purple', capsize=3, marker='.',color='magenta',label='magenta')
y20m = np.round(y20[5:].mean(),2)
plt.axhline(y20m, linestyle='--', color='gray', label=None)
plt.text(0.15,y20m, str(y20m), va='center', ha='center', backgroundcolor='w')
plt.title('Filament 5', fontsize=14)
plt.xlabel('Active motor ratio')
plt.xticks(np.arange(0.0,1.2,step=0.2))
plt.yticks(np.arange(0,13,step=2))
plt.ylim(0,12)
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)

plt.subplot(2,3,6)
plt.plot(x,y4,color='green',label='Filament 1')
plt.plot(x,y8,color='red',label='Filament 2')
plt.plot(x,y12,color='blue',label='Filament 3')
plt.plot(x,y16,color='orange',label='Filament 4')
plt.plot(x,y20,color='magenta',label='Filament 5')
plt.errorbar(x,avi,yerr=vsd, mec='black', capsize=2.5, marker='.', markersize=7, linestyle='--', ecolor='black',color='grey',label='Speed deviation')
yavim = np.round(avi[5:].mean(),2)
plt.axhline(yavim, linestyle='--', color='gray', label=None)
plt.text(0.15,yavim, str(yavim), va='center', ha='center', backgroundcolor='w')
plt.title('All 5 filaments', fontsize=14)
plt.xlabel('Active motor ratio', fontsize=14)
plt.xticks(np.arange(0.0,1.2,step=0.2))
plt.yticks(np.arange(-0.0,12.1,step=2))
plt.ylim(0,12)
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
#plt.legend(loc='upper left')

plt.savefig('10nmFilament.svg',fmt='svg',dip=500,bbox_inches='tight')

# %%
vsd
# Out:
# array([0.15895733, 0.17269741, 2.04595408, 0.80279313, 0.35625145,
#        0.20125679, 0.16997328, 0.2706943 , 0.16807497, 0.11838958])

# %%
plt.figure(figsize=(10,8))
plt.axis('tight')

plt.errorbar(x,avi,yerr=vsd, mec='black', capsize=4, marker='o', markersize=7, linestyle='--', ecolor='black',color='black',label='Speed deviation')
avim = np.round(avi[5:].mean(),2)
#plt.axhline(avim, linestyle='--', color='gray', label='Average grinding speed')
#plt.text(0.15,avim, str(avim), va='center', ha='center', backgroundcolor='w')
#plt.title('Actin Filament Grinding Speed')
plt.xlabel('Active myosin ratio', fontsize=18)
plt.ylabel('Speed ($\mu m/sec$)', fontsize=18)
#plt.legend(loc='upper left')
plt.xticks(np.arange(0.0,1.3,step=0.2),fontsize=18)
plt.yticks(np.arange(0,11,step=2),fontsize=18)
#plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
plt.title('Figure 2: Shuttle speed against active motor ratio', y=-0.165, fontsize=18)

plt.savefig('allAvSpeed.svg',fmt='svg',dip=2000,bbox_inches='tight')
plt.savefig('allAvSpeed.png',fmt='png',dip=5000,bbox_inches='tight')

# %%
plt.figure(figsize=(15,6))
#plt.axis('tight')
#plt.suptitle('Actin Filament Grinding Trajectory [dt = 0.01]')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.25)
plt.axes().set_aspect('equal')

plt.subplot(2,5,1)
plt.plot(df01['x'],df01['y'], label='Leading tip', color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,25,step=6))
plt.yticks(np.arange(-18,7,step=6))
plt.ylabel('Y ($\mu m$)', fontsize=14)
plt.title('Ratio = 0.1', fontsize=14)
#plt.legend(loc='upper left')

plt.subplot(2,5,2)
plt.plot(df02['x'],df02['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,25,step=6))
plt.yticks(np.arange(-18,7,step=6))
plt.title('Ratio = 0.2', fontsize=14)

plt.subplot(2,5,3)
plt.plot(df03['x'],df03['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,25,step=6))
plt.yticks(np.arange(-18,7,step=6))
plt.title('Ratio = 0.3', fontsize=14)

plt.subplot(2,5,4)
plt.plot(df04['x'],df04['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,25,step=6))
plt.yticks(np.arange(-18,7,step=6))
plt.title('Ratio = 0.4', fontsize=14)

plt.subplot(2,5,5)
plt.plot(df05['x'],df05['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,25,step=6))
plt.yticks(np.arange(-18,7,step=6))
plt.title('Ratio = 0.5', fontsize=14)

plt.subplot(2,5,6)
plt.plot(df06['x'],df06['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,25,step=6))
plt.yticks(np.arange(-18,7,step=6))
plt.xlabel('X ($\mu m$)', fontsize=14)
plt.ylabel('Y ($\mu m$)', fontsize=14)
plt.title('Ratio = 0.6', fontsize=14)

plt.subplot(2,5,7)
plt.plot(df07['x'],df07['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,25,step=6))
plt.yticks(np.arange(-18,7,step=6))
plt.xlabel('X ($\mu m$)', fontsize=14)
plt.title('Ratio = 0.7', fontsize=14)

plt.subplot(2,5,8)
plt.plot(df08['x'],df08['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,25,step=6))
plt.yticks(np.arange(-18,7,step=6))
plt.xlabel('X ($\mu m$)', fontsize=14)
plt.title('Ratio = 0.8', fontsize=14)

plt.subplot(2,5,9)
plt.plot(df09['x'],df09['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,25,step=6))
plt.yticks(np.arange(-18,7,step=6))
plt.xlabel('X ($\mu m$)', fontsize=14)
plt.title('Ratio = 0.9', fontsize=14)

plt.subplot(2,5,10)
plt.plot(df10['x'],df10['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,25,step=6))
plt.yticks(np.arange(-18,7,step=6))
plt.xlabel('X ($\mu m$)', fontsize=14)
plt.title('Ratio = 1.0', fontsize=14)

#plt.savefig('allTraj.svg',fmt='svg',dip=500,bbox_inches='tight')
plt.savefig('allTraj.png',fmt='png',dip=700,bbox_inches='tight')

# %%
# filament 3 pc8 seed 97845 09-02-2019

columnsn = ['t', 'x', 'y']

fil3_1 = pd.read_csv('TipXY_01_10nm_seed97845.txt', names=columnsn, delim_whitespace=True)
fil3_1 = fil3_1.drop(['t'], axis=1) # dt = 0.01*1 = 0.01 sec
fil01 = fil3_1.iloc[0::10, :] #pick every 9th row starting from the first. Here dt = 0.01*10 = 0.1

fil3_2 = pd.read_csv('TipXY_02_10nm_seed97845.txt', names=columnsn, delim_whitespace=True)
fil3_2 = fil3_2.drop(['t'], axis=1)
fil02 = fil3_2.iloc[0::10, :]

fil3_3 = pd.read_csv('TipXY_03_10nm_seed97845.txt', names=columnsn, delim_whitespace=True)
fil3_3 = fil3_3.drop(['t'], axis=1)
fil03 = fil3_3.iloc[0::10, :]

fil3_4 = pd.read_csv('TipXY_04_10nm_seed97845.txt', names=columnsn, delim_whitespace=True)
fil3_4 = fil3_4.drop(['t'], axis=1)
fil04 = fil3_4.iloc[0::10, :]

fil3_5 = pd.read_csv('TipXY_05_10nm_seed97845.txt', names=columnsn, delim_whitespace=True)
fil3_5 = fil3_5.drop(['t'], axis=1)
fil05 = fil3_5.iloc[0::10, :]

fil3_6 = pd.read_csv('TipXY_06_10nm_seed97845.txt', names=columnsn, delim_whitespace=True)
fil3_6 = fil3_6.drop(['t'], axis=1)
fil06 = fil3_6.iloc[0::10, :]

fil3_7 = pd.read_csv('TipXY_07_10nm_seed97845.txt', names=columnsn, delim_whitespace=True)
fil3_7 = fil3_7.drop(['t'], axis=1)
fil07 = fil3_7.iloc[0::10, :]

fil3_8 = pd.read_csv('TipXY_08_10nm_seed97845.txt', names=columnsn, delim_whitespace=True)
fil3_8 = fil3_8.drop(['t'], axis=1)
fil08 = fil3_8.iloc[0::10, :]

fil3_9 = pd.read_csv('TipXY_09_10nm_seed97845.txt', names=columnsn, delim_whitespace=True)
fil3_9 = fil3_9.drop(['t'], axis=1)
fil09 = fil3_9.iloc[0::10, :]

fil3_10 = pd.read_csv('TipXY_10_10nm_seed97845.txt', names=columnsn, delim_whitespace=True)
fil3_10 = fil3_10.drop(['t'], axis=1)
fil10 = fil3_10.iloc[0::10, :]

# %%
fil3_10
# Out:
#              x         y
# 0     4.000000  0.000000
# 1     4.064873  0.028654
# 2     4.133609  0.018834
# 3     4.185099  0.080637
# 4     4.271278  0.059963
# 5     4.337936  0.028490
# 6     4.397058 -0.006839
# 7     4.452703 -0.003210
# 8     4.445048 -0.349035
# 9     4.483489 -0.434444
# 10    4.518399 -0.495141
# 11    4.720569 -0.251409
# 12    4.738641 -0.397050
# 13    4.866337 -0.296194
# 14    4.929992 -0.312051
# 15    4.989379 -0.308651
# 16    5.037372 -0.308456
# 17    5.107496 -0.308032
# 18    5.165461 -0.359555
# 19    5.229236 -0.396217
# 20    5.296111 -0.399502
# 21    5.407298 -0.329560
# 22    5.474746 -0.199371
# 23    5.529653 -0.300232
# 24    5.597956 -0.406275
# 25    5.654341 -0.426241
# 26    5.726923 -0.444130
# 27    5.782856 -0.455984
# 28    5.816121 -0.537586
# 29    5.889708 -0.514709
# ..         ...       ...
# 271  10.582174 -7.917153
# 272  10.518476 -7.888767
# 273  10.462482 -7.916865
# 274  10.416420 -7.895620
# 275  10.329487 -7.905811
# ...

# %%
# dt = 0.1
plt.figure(figsize=(15,6))
#plt.axis('tight')
#plt.suptitle('Actin Filament Grinding Trajectory [dt = 0.01]')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.25)
plt.axes().set_aspect('equal')

plt.subplot(2,5,1)
plt.plot(fil01['x'],fil01['y'], label='Leading tip', color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,26,step=8))
plt.yticks(np.arange(-10,16,step=6))
plt.ylabel('Y ($\mu m$)', fontsize=14)
plt.title('Ratio = 0.1', fontsize=14)
#plt.legend(loc='upper left')

plt.subplot(2,5,2)
plt.plot(fil02['x'],fil02['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,26,step=8))
plt.yticks(np.arange(-10,16,step=6))
plt.title('Ratio = 0.2', fontsize=14)

plt.subplot(2,5,3)
plt.plot(fil03['x'],fil03['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,26,step=8))
plt.yticks(np.arange(-10,16,step=6))
plt.title('Ratio = 0.3', fontsize=14)

plt.subplot(2,5,4)
plt.plot(fil04['x'],fil04['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,26,step=8))
plt.yticks(np.arange(-10,16,step=6))
plt.title('Ratio = 0.4', fontsize=14)

plt.subplot(2,5,5)
plt.plot(fil05['x'],fil05['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,26,step=8))
plt.yticks(np.arange(-10,16,step=6))
plt.title('Ratio = 0.5', fontsize=14)

plt.subplot(2,5,6)
plt.plot(fil06['x'],fil06['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,26,step=8))
plt.yticks(np.arange(-10,16,step=6))
plt.xlabel('X ($\mu m$)', fontsize=14)
plt.ylabel('Y ($\mu m$)', fontsize=14)
plt.title('Ratio = 0.6', fontsize=14)

plt.subplot(2,5,7)
plt.plot(fil07['x'],fil07['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,26,step=8))
plt.yticks(np.arange(-10,16,step=6))
plt.xlabel('X ($\mu m$)', fontsize=14)
plt.title('Ratio = 0.7', fontsize=14)

plt.subplot(2,5,8)
plt.plot(fil08['x'],fil08['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,26,step=8))
plt.yticks(np.arange(-10,16,step=6))
plt.xlabel('X ($\mu m$)', fontsize=14)
plt.title('Ratio = 0.8', fontsize=14)

plt.subplot(2,5,9)
plt.plot(fil09['x'],fil09['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,26,step=8))
plt.yticks(np.arange(-10,16,step=6))
plt.xlabel('X ($\mu m$)', fontsize=14)
plt.title('Ratio = 0.9', fontsize=14)

plt.subplot(2,5,10)
plt.plot(fil10['x'],fil10['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,26,step=8))
plt.yticks(np.arange(-10,16,step=6))
plt.xlabel('X ($\mu m$)', fontsize=14)
plt.title('Ratio = 1.0', fontsize=14)

#plt.savefig('allTraj.svg',fmt='svg',dip=500,bbox_inches='tight')
plt.savefig('allTraj.png',fmt='png',dip=700,bbox_inches='tight')

# %%
# dt = 0.01
plt.figure(figsize=(15,6))
#plt.axis('tight')
#plt.suptitle('Actin Filament Grinding Trajectory [dt = 0.01]')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.25)
plt.axes().set_aspect('equal')

plt.subplot(2,5,1)
plt.plot(fil3_1['x'],fil3_1['y'], label='Leading tip', color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,26,step=8))
plt.yticks(np.arange(-10,16,step=6))
plt.ylabel('Y ($\mu m$)', fontsize=14)
plt.title('Ratio = 0.1', fontsize=14)
#plt.legend(loc='upper left')

plt.subplot(2,5,2)
plt.plot(fil3_2['x'],fil3_2['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,26,step=8))
plt.yticks(np.arange(-10,16,step=6))
plt.title('Ratio = 0.2', fontsize=14)

plt.subplot(2,5,3)
plt.plot(fil3_3['x'],fil3_3['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,26,step=8))
plt.yticks(np.arange(-10,16,step=6))
plt.title('Ratio = 0.3', fontsize=14)

plt.subplot(2,5,4)
plt.plot(fil3_4['x'],fil3_4['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,26,step=8))
plt.yticks(np.arange(-10,16,step=6))
plt.title('Ratio = 0.4', fontsize=14)

plt.subplot(2,5,5)
plt.plot(fil3_5['x'],fil3_5['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,26,step=8))
plt.yticks(np.arange(-10,16,step=6))
plt.title('Ratio = 0.5', fontsize=14)

plt.subplot(2,5,6)
plt.plot(fil3_6['x'],fil3_6['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,26,step=8))
plt.yticks(np.arange(-10,16,step=6))
plt.xlabel('X ($\mu m$)', fontsize=14)
plt.ylabel('Y ($\mu m$)', fontsize=14)
plt.title('Ratio = 0.6', fontsize=14)

plt.subplot(2,5,7)
plt.plot(fil3_7['x'],fil3_7['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,26,step=8))
plt.yticks(np.arange(-10,16,step=6))
plt.xlabel('X ($\mu m$)', fontsize=14)
plt.title('Ratio = 0.7', fontsize=14)

plt.subplot(2,5,8)
plt.plot(fil3_8['x'],fil3_8['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,26,step=8))
plt.yticks(np.arange(-10,16,step=6))
plt.xlabel('X ($\mu m$)', fontsize=14)
plt.title('Ratio = 0.8', fontsize=14)

plt.subplot(2,5,9)
plt.plot(fil3_9['x'],fil3_9['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,26,step=8))
plt.yticks(np.arange(-10,16,step=6))
plt.xlabel('X ($\mu m$)', fontsize=14)
plt.title('Ratio = 0.9', fontsize=14)

plt.subplot(2,5,10)
plt.plot(fil3_10['x'],fil3_10['y'], color='black', marker='.', linestyle='dashed', linewidth=1, markersize=7)
plt.xticks(np.arange(-2,26,step=8))
plt.yticks(np.arange(-10,16,step=6))
plt.xlabel('X ($\mu m$)', fontsize=14)
plt.title('Ratio = 1.0', fontsize=14)

#plt.savefig('allTraj.svg',fmt='svg',dip=500,bbox_inches='tight')
plt.savefig('allTraj.png',fmt='png',dip=700,bbox_inches='tight')

# %%
# dt = 0.01 modified
plt.figure(figsize=(15,6))
#plt.axis('tight')
plt.suptitle('Actin Filament Grinding Trajectory [dt = 0.01]', fontsize=18)
#plt.suptitle('Figure 1: Representative shuttle trajectories', y=-0.0001, fontsize=18)
plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)
plt.axes().set_aspect('equal')

plt.subplot(2,5,1)
plt.plot(fil3_1['x'],fil3_1['y'], label='Leading tip', color='black', marker='.', linestyle='-', linewidth=0.5, markersize=7)
plt.xticks(np.arange(-5,26,step=10),fontsize=14)
plt.yticks(np.arange(-15,16,step=10),fontsize=14)
plt.ylabel('Y ($\mu m$)', fontsize=16)
plt.title('Ratio = 0.1', fontsize=16)
#plt.legend(loc='upper left')

plt.subplot(2,5,2)
plt.plot(fil3_2['x'],fil3_2['y'], color='black', marker='.', linestyle='-', linewidth=0.5, markersize=1)
plt.xticks(np.arange(-5,26,step=10),fontsize=14)
plt.yticks(np.arange(-15,16,step=10),fontsize=14)
plt.title('Ratio = 0.2', fontsize=16)

plt.subplot(2,5,3)
plt.plot(fil3_3['x'],fil3_3['y'], color='black', marker='.', linestyle='-', linewidth=0.5, markersize=1)
plt.xticks(np.arange(-5,26,step=10),fontsize=14)
plt.yticks(np.arange(-15,16,step=10),fontsize=14)
plt.title('Ratio = 0.3', fontsize=16)

plt.subplot(2,5,4)
plt.plot(fil3_4['x'],fil3_4['y'], color='black', marker='.', linestyle='-', linewidth=0.5, markersize=1)
plt.xticks(np.arange(-5,26,step=10),fontsize=14)
plt.yticks(np.arange(-15,16,step=10),fontsize=14)
plt.title('Ratio = 0.4', fontsize=16)

plt.subplot(2,5,5)
plt.plot(fil3_5['x'],fil3_5['y'], color='black', marker='.', linestyle='-', linewidth=0.5, markersize=1)
plt.xticks(np.arange(-5,26,step=10),fontsize=14)
plt.yticks(np.arange(-15,16,step=10),fontsize=14)
plt.title('Ratio = 0.5', fontsize=16)

plt.subplot(2,5,6)
plt.plot(fil3_6['x'],fil3_6['y'], color='black', marker='.', linestyle='-', linewidth=0.5, markersize=1)
plt.xticks(np.arange(-5,26,step=10),fontsize=14)
plt.yticks(np.arange(-15,16,step=10),fontsize=14)
plt.xlabel('X ($\mu m$)', fontsize=16)
plt.ylabel('Y ($\mu m$)', fontsize=16)
plt.title('Ratio = 0.6', fontsize=16)

plt.subplot(2,5,7)
plt.plot(fil3_7['x'],fil3_7['y'], color='black', marker='.', linestyle='-', linewidth=0.5, markersize=1)
plt.xticks(np.arange(-5,26,step=10),fontsize=14)
plt.yticks(np.arange(-15,16,step=10),fontsize=14)
plt.xlabel('X ($\mu m$)', fontsize=16)
plt.title('Ratio = 0.7', fontsize=16)

plt.subplot(2,5,8)
plt.plot(fil3_8['x'],fil3_8['y'], color='black', marker='.', linestyle='-', linewidth=0.5, markersize=1)
plt.xticks(np.arange(-5,26,step=10),fontsize=14)
plt.yticks(np.arange(-15,16,step=10),fontsize=14)
plt.xlabel('X ($\mu m$)', fontsize=16)
plt.title('Ratio = 0.8', fontsize=16)

plt.subplot(2,5,9)
plt.plot(fil3_9['x'],fil3_9['y'], color='black', marker='.', linestyle='-', linewidth=0.5, markersize=1)
plt.xticks(np.arange(-5,26,step=10),fontsize=14)
plt.yticks(np.arange(-15,16,step=10),fontsize=14)
plt.xlabel('X ($\mu m$)', fontsize=16)
plt.title('Ratio = 0.9', fontsize=16)

plt.subplot(2,5,10)
plt.plot(fil3_10['x'],fil3_10['y'], color='black', marker='.', linestyle='-', linewidth=0.5, markersize=1)
plt.xticks(np.arange(-5,26,step=10),fontsize=14)
plt.yticks(np.arange(-15,16,step=10),fontsize=14)
plt.xlabel('X ($\mu m$)', fontsize=16)
plt.title('Ratio = 1.0', fontsize=16)

plt.savefig('allTraj.svg',fmt='svg',dip=3000,bbox_inches='tight')
plt.savefig('allTraj.png',fmt='png',dip=5000,bbox_inches='tight')

# %%
plt.figure(figsize=(15,7))
plt.axis('tight')
plt.suptitle('Binding Motor Number Histogram [ATP = 2000, MD = 3000, Step size = 10 nm]', fontsize=18)
df10 = bm_10['b_m'].T; df9 = bm_09['b_m'].T; df8 = bm_08['b_m'].T; df7 = bm_07['b_m'].T
df6 = bm_06['b_m'].T; df5 = bm_05['b_m'].T
byn = 20

plt.subplots_adjust(wspace=0.2)
plt.subplots_adjust(hspace=0.3)

plt.subplot(2,3,1)
(mu,sigma)=norm.fit(df10)
n,bins,patches = plt.hist(df10, byn, density=True, alpha=1,histtype='bar',ec='black',color='green',label='')
plt.plot(bins,1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2)),'b-',lw=1.3, label='Gaussian fit')
plt.yticks(np.arange(0,0.14,step=0.02))
plt.xticks(np.arange(0,50,step=5))
plt.ylabel('Density', fontsize=14)
plt.title(r'Motor ratio = 1.0, $\mu=%d,\ \sigma=%d$' %(mu, sigma))
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
plt.legend(loc='upper left')

plt.subplot(2,3,2)
(mu,sigma)=norm.fit(df9)
n,bins,patches = plt.hist(df9,byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
plt.plot(bins,1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2)),'b-',lw=1.3)
plt.yticks(np.arange(0,0.14,step=0.02))
plt.xticks(np.arange(0,50,step=5))
plt.title(r'Motor ratio = 0.9, $\mu=%d,\ \sigma=%d$' %(mu, sigma))
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)

plt.subplot(2,3,3)
(mu,sigma)=norm.fit(df8)
n,bins,patches = plt.hist(df8,byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
plt.plot(bins,1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2)),'b-',lw=1.3)
plt.yticks(np.arange(0,0.14,step=0.02))
plt.xticks(np.arange(0,50,step=5))
plt.title(r'Motor ratio = 0.8, $\mu=%d,\ \sigma=%d$' %(mu, sigma))
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)

plt.subplot(2,3,4)
(mu,sigma)=norm.fit(df7)
n,bins,patches = plt.hist(df7,byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
plt.plot(bins,1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2)),'b-',lw=1.3)
plt.yticks(np.arange(0,0.14,step=0.02))
plt.xticks(np.arange(0,50,step=5))
plt.ylabel('Density', fontsize=14)
plt.title(r'Motor ratio = 0.7, $\mu=%d,\ \sigma=%d$' %(mu, sigma))
plt.xlabel('Binding motor number', fontsize=14)
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)

plt.subplot(2,3,5)
(mu,sigma)=norm.fit(df6)
n,bins,patches = plt.hist(df6,byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
plt.plot(bins,1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2)),'b-',lw=1.3)
plt.yticks(np.arange(0,0.14,step=0.02))
plt.xticks(np.arange(0,50,step=5))
plt.title(r'Motor ratio = 0.6, $\mu=%d,\ \sigma=%d$' %(mu, sigma))
plt.xlabel('Binding motor number', fontsize=14)
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)

plt.subplot(2,3,6)
(mu,sigma)=(df5.mean(),np.std(df5))#norm.fit(df5)
plt.hist(df5,byn, density=True, alpha=1,histtype='bar',ec='black',color='green')
#plt.plot(bins,1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2)),'r-',lw=1.3)
#plt.yticks(np.arange(0,0.14,step=0.02))
#plt.xticks(np.arange(0,65,step=5))
plt.title(r'Motor ratio = 0.5, $\mu=%d,\ \sigma=%d$' %(mu, sigma))
plt.xlabel('Binding motor number', fontsize=14)
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)

plt.savefig('bmnHist.svg',fmt='svg',dip=3000,bbox_inches='tight')

# %%
plt.figure(figsize=(15,7))
plt.axis('tight')
plt.suptitle('Actin Filament Grinding Speed [ATP = 2000, MD = 3000, Step size = 10 nm to 2.5 nm]')

plt.subplot(2,3,1)
plt.errorbar(x,y4,yerr=dev4, mec='purple', capsize=3, marker='.',color='green',label='Speed deviation')
y4m = np.round(y4[5:].mean(),2)
plt.axhline(y4m, linestyle='--', color='gray', label='Average grinding speed')
plt.text(0.15,y4m, str(y4m), va='center', ha='center', backgroundcolor='w')
plt.title('Filament 1, step size = 10 nm')
plt.ylabel('Speed ($\mu m/sec$)')
plt.legend(loc='upper left')
plt.xticks(np.arange(0.1,1.1,step=0.1))
plt.yticks(np.arange(0,13,step=2))
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)

plt.subplot(2,3,2)
#plt.errorbar(x,y8,yerr=dev8, mec='purple', capsize=3, marker='.',color='red',label=None)
plt.errorbar(x,y3,yerr=dev3, mec='purple', capsize=3, color='red', marker='.', label=None)
y3m = np.round(y3[5:].mean(),2)
plt.axhline(y3m, linestyle='--', color='gray', label=None)
plt.text(0.15,y3m, str(y3m), va='center', ha='center', backgroundcolor='w')
plt.title('Filament 1, step size = 7.5 nm')
plt.xticks(np.arange(0.1,1.1,step=0.1))
plt.yticks(np.arange(0,13,step=2))
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)

plt.subplot(2,3,3)
#plt.errorbar(x,y12,yerr=dev12, mec='purple', capsize=3, marker='.',color='blue',label=None)
plt.errorbar(x,y2,yerr=dev2, mec='purple', capsize=3, color='blue', marker='.', label=None)
y2m = np.round(y2[5:].mean(),2)
plt.axhline(y2m, linestyle='--', color='gray', label=None)
plt.text(0.15,y2m, str(y2m), va='center', ha='center', backgroundcolor='w')
plt.title('Filament 1, step size = 5 nm')
plt.xticks(np.arange(0.1,1.1,step=0.1))
plt.yticks(np.arange(0,13,step=2))
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)

plt.subplot(2,3,4)
#plt.errorbar(x,y16,yerr=dev16, mec='purple', capsize=3, marker='.',color='orange',label=None)
plt.errorbar(x,y1,yerr=dev1, mec='purple', capsize=3, color='orange', marker='.', label=None)
y1m = np.round(y1[5:].mean(),2)
plt.axhline(y1m, linestyle='--', color='gray', label=None)
plt.text(0.15,y1m, str(y1m), va='center', ha='center', backgroundcolor='w')
plt.title('Filament 1, step size = 2.5 nm')
plt.xlabel('Active motor ratio')
plt.ylabel('Speed ($\mu m/sec$)')
plt.xticks(np.arange(0.1,1.1,step=0.1))
plt.yticks(np.arange(0,13,step=2))
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)

plt.subplot(2,3,5)
plt.plot(x,y4,color='green',label= 'Step size = 10 nm')
plt.plot(x,y3,color='red',label='Step size = 7.5 nm')
plt.plot(x,y2,color='blue',label='Step size = 5 nm')
plt.plot(x,y1,color='orange',label='Step size = 2.5 nm')
plt.title('Filament 1, step size 10 to 2.5')
plt.xlabel('Active motor ratio')
plt.xticks(np.arange(0.1,1.1,step=0.1))
plt.yticks(np.arange(0,13,step=2))
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
plt.legend(loc='upper left')

plt.subplot(2,3,6)
plt.plot(x,y4, color='green', label='Step size = 10 nm')
plt.plot(x,y3, color='red', label='Step size = 7.5 nm')
plt.plot(x,y2, color='blue', label='Step size = 5 nm')
plt.plot(x,y1, color='orange', label='Step size = 2.5 nm')

# sorry the order changed to ascending i.e., y5 to y8 instead of vice versa
plt.plot(x,y5, color='orange', label='')
plt.plot(x,y6, color='blue', label='')
plt.plot(x,y7, color='red', label='')
plt.plot(x,y8, color='green', label='')

plt.plot(x,y9, color='orange', label='')
plt.plot(x,y10, color='blue', label='')
plt.plot(x,y11, color='red', label='')
plt.plot(x,y12, color='green', label='')

plt.plot(x,y13, color='orange', label='')
plt.plot(x,y14, color='blue', label='')
plt.plot(x,y15, color='red', label='')
plt.plot(x,y16, color='green', label='')

plt.plot(x,y17, color='orange', label='')
plt.plot(x,y18, color='blue', label='')
plt.plot(x,y19, color='red', label='')
plt.plot(x,y20, color='green', label='')



plt.title('5 filaments, step size 10 to 2.5')
plt.xlabel('Active motor ratio')
plt.xticks(np.arange(0.1,1.1,step=0.1))
plt.yticks(np.arange(0,13,step=2))
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
#plt.legend(loc='upper left')

plt.savefig('Stepsize.svg',fmt='svg',dip=500,bbox_inches='tight')

# %%
[np.round(y4[5:].mean(),2), np.round(y3[5:].mean(),2), np.round(y2[5:].mean(),2), np.round(y1[5:].mean(),2)]
# Out:
# [7.32, 5.11, 3.41, 1.56]

# %%
atp = np.array([300,600,900,1200,1500,1800,2100,2400,2700,3000,3300])
columns = ['speed','deviation']
r05 = pd.read_csv('R05speedATP.csv',names=columns)
r06 = pd.read_csv('R06speedATP.csv',names=columns)
r07 = pd.read_csv('R07speedATP.csv',names=columns)
r08 = pd.read_csv('R08speedATP.csv',names=columns)
r09 = pd.read_csv('R09speedATP.csv',names=columns)
r10 = pd.read_csv('R10speedATP.csv',names=columns)

# %%
from scipy.interpolate import spline
from scipy.optimize import curve_fit

# %%
plt.figure(figsize=(15,7))
plt.axis('tight')
plt.suptitle('ATP vs. Actin Filament Grinding Speed [MD = 3000]', fontsize=16)

plt.subplots_adjust(wspace=0.2)
plt.subplots_adjust(hspace=0.5)

plt.subplot(2,3,1) # ===================================================
x = atp; y = r10['speed']; sDev = r10['deviation']

plt.errorbar(x,y,yerr=sDev, ecolor='dodgerblue', capsize=3, \
             mec='purple', color='green', marker='o', linestyle='--', linewidth=1, \
             markersize=5, label='Simulation results')

xN = np.linspace(x.min(),x.max(),100)
sDevS = spline(x,sDev,xN)
ys = spline(x,y,xN)

plt.fill_between(xN,ys-sDevS,ys+sDevS,alpha=0.4,edgecolor='#CC4F18',facecolor='#FF9848', label='Speed deviation')

def func(x,km):
    return (x*y.max())/(x+km)
popt, pcov = curve_fit(func, x,y)

plt.plot(x,func(x,*popt),'g-', lw=2.5, label="Michaelis-Menten's fitting")

kmVal = popt[0]
yVal = (kmVal*y.max())/(kmVal+popt[0])
#plt.axhline(yVal, linestyle='--', color='gray', label='Average grinding speed')
#plt.text(2,yVal, str(round(yVal,2)), va='center', ha='center', backgroundcolor='w')

plt.xticks(np.arange(0,3300,step=600))
plt.yticks(np.arange(2,13,step=2))

plt.ylabel('Speed ($\mu m/sec$)', fontsize=14)
plt.title(r'Ratio = 1.0, $k_M\ =\ %0.2f,\ \frac{1}{2}v_{max}\ =\ %0.2f$'%(kmVal,yVal))
plt.legend(loc='lower right')
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)

plt.subplot(2,3,2) # ===================================================
x = atp; y = r09['speed']; sDev = r09['deviation']

plt.errorbar(x,y,yerr=sDev, ecolor='dodgerblue', capsize=3, \
             mec='purple', color='green', marker='o', linestyle='--', linewidth=1, \
             markersize=5, label='Simulation results')

xN = np.linspace(x.min(),x.max(),100)
sDevS = spline(x,sDev,xN)
ys = spline(x,y,xN)

plt.fill_between(xN,ys-sDevS,ys+sDevS,alpha=0.4,edgecolor='#CC4F18',facecolor='#FF9848', label='Speed deviation')

def func(x,km):
    return (x*y.max())/(x+km)
popt, pcov = curve_fit(func, x,y)

plt.plot(x,func(x,*popt),'g-', lw=2.5, label="Michaelis-Menten's fitting")

kmVal = popt[0]
yVal = (kmVal*y.max())/(kmVal+popt[0])

plt.xticks(np.arange(0,3300,step=600))
plt.yticks(np.arange(2,13,step=2))

plt.title(r'Ratio = 0.9, $k_M\ =\ %0.2f,\ \frac{1}{2}v_{max}\ =\ %0.2f$'%(kmVal,yVal))
#plt.legend(loc='lower right')
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)

plt.subplot(2,3,3) # ===================================================
x = atp; y = r08['speed']; sDev = r08['deviation']

plt.errorbar(x,y,yerr=sDev, ecolor='dodgerblue', capsize=3, \
             mec='purple', color='green', marker='o', linestyle='--', linewidth=1, \
             markersize=5, label='Simulation results')

xN = np.linspace(x.min(),x.max(),100)
sDevS = spline(x,sDev,xN)
ys = spline(x,y,xN)

plt.fill_between(xN,ys-sDevS,ys+sDevS,alpha=0.4,edgecolor='#CC4F18',facecolor='#FF9848', label='Speed deviation')

def func(x,km):
    return (x*y.max())/(x+km)
popt, pcov = curve_fit(func, x,y)

plt.plot(x,func(x,*popt),'g-', lw=2.5, label="Michaelis-Menten's fitting")

kmVal = popt[0]
yVal = (kmVal*y.max())/(kmVal+popt[0])

plt.xticks(np.arange(0,3300,step=600))
plt.yticks(np.arange(2,13,step=2))

plt.title(r'Ratio = 0.8, $k_M\ =\ %0.2f,\ \frac{1}{2}v_{max}\ =\ %0.2f$'%(kmVal,yVal))
#plt.legend(loc='lower right')
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)

plt.subplot(2,3,4) # ===================================================
x = atp; y = r07['speed']; sDev = r07['deviation']

plt.errorbar(x,y,yerr=sDev, ecolor='dodgerblue', capsize=3, \
             mec='purple', color='green', marker='o', linestyle='--', linewidth=1, \
             markersize=5, label='Simulation results')

xN = np.linspace(x.min(),x.max(),100)
sDevS = spline(x,sDev,xN)
ys = spline(x,y,xN)

plt.fill_between(xN,ys-sDevS,ys+sDevS,alpha=0.4,edgecolor='#CC4F18',facecolor='#FF9848', label='Speed deviation')

def func(x,km):
    return (x*y.max())/(x+km)
popt, pcov = curve_fit(func, x,y)

plt.plot(x,func(x,*popt),'g-', lw=2.5, label="Michaelis-Menten's fitting")

kmVal = popt[0]
yVal = (kmVal*y.max())/(kmVal+popt[0])

plt.xticks(np.arange(0,3300,step=600))
plt.yticks(np.arange(2,13,step=2))

plt.xlabel('ATP', fontsize=14); plt.ylabel('Speed ($\mu m/sec$)', fontsize=14)
plt.title(r'Ratio = 0.7, $k_M\ =\ %0.2f,\ \frac{1}{2}v_{max}\ =\ %0.2f$'%(kmVal,yVal))
#plt.legend(loc='lower right')
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)

plt.subplot(2,3,5) # ===================================================
x = atp; y = r06['speed']; sDev = r06['deviation']

plt.errorbar(x,y,yerr=sDev, ecolor='dodgerblue', capsize=3, \
             mec='purple', color='green', marker='o', linestyle='--', linewidth=1, \
             markersize=5, label='Simulation results')

xN = np.linspace(x.min(),x.max(),100)
sDevS = spline(x,sDev,xN)
ys = spline(x,y,xN)

plt.fill_between(xN,ys-sDevS,ys+sDevS,alpha=0.4,edgecolor='#CC4F18',facecolor='#FF9848', label='Speed deviation')

def func(x,km):
    return (x*y.max())/(x+km)
popt, pcov = curve_fit(func, x,y)

plt.plot(x,func(x,*popt),'g-', lw=2.5, label="Michaelis-Menten's fitting")

kmVal = popt[0]
yVal = (kmVal*y.max())/(kmVal+popt[0])

plt.xticks(np.arange(0,3300,step=600))
plt.yticks(np.arange(2,13,step=2))

plt.xlabel('ATP', fontsize=14)
plt.title(r'Ratio = 0.6, $k_M\ =\ %0.2f,\ \frac{1}{2}v_{max}\ =\ %0.2f$'%(kmVal,yVal))
#plt.legend(loc='lower right')
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)

plt.subplot(2,3,6) # ===================================================
x = atp; y = r05['speed']; sDev = r05['deviation']

plt.errorbar(x,y,yerr=sDev, ecolor='dodgerblue', capsize=3, \
             mec='purple', color='green', marker='o', linestyle='--', linewidth=1, \
             markersize=5, label='Simulation results')

xN = np.linspace(x.min(),x.max(),100)
sDevS = spline(x,sDev,xN)
ys = spline(x,y,xN)

plt.fill_between(xN,ys-sDevS,ys+sDevS,alpha=0.4,edgecolor='#CC4F18',facecolor='#FF9848', label='Speed deviation')

def func(x,km):
    return (x*y.max())/(x+km)
popt, pcov = curve_fit(func, x,y)

plt.plot(x,func(x,*popt),'g-', lw=2.5, label="Michaelis-Menten's fitting")

kmVal = popt[0]
yVal = (kmVal*y.max())/(kmVal+popt[0])

plt.xticks(np.arange(0,3300,step=600))
plt.yticks(np.arange(2,13,step=2))

plt.xlabel('ATP', fontsize=14)
plt.title(r'Ratio = 0.5, $k_M\ =\ %0.2f,\ \frac{1}{2}v_{max}\ =\ %0.2f$'%(kmVal,yVal))
#plt.legend(loc='lower right')
plt.subplots_adjust(hspace=0.25)
plt.grid(color='gray',which='both',linestyle=':',linewidth=0.25)
plt.savefig('speedATP.svg',fmt='svg',dip=3000,bbox_inches='tight')
# Out:
# /home/nitta/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#   app.launch_new_instance()
# /home/nitta/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
# /home/nitta/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:48: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
# /home/nitta/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:49: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
# /home/nitta/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:77: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
# ...
